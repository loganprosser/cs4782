# %% [markdown]
# ## <h1><center><b>Project 5: Reinforcement Learning</b></center></h1>
#
# <center><img src="https://www.cs.cornell.edu/courses/cs4782/2025sp/images/p5_rl_header.jpeg"></center>
#
# In this project, we will explore fundamental reinforcement learning algorithms: Q-Learning, Deep Q-Networks (DQNs), and Policy Gradient Methods. We will implement these algorithms to train agents to play classic control environments from the OpenAI Gym library.
#
# &nbsp;
#
# ---
#
# **DO's:**
#
# 1.   **Running on GPU should not be necessary for this assignment.** You should be able to use the *free* Colab **T4 GPU** runtime to make your training faster, but most cells should take under 5 minutes, even on CPU.
# 2.   As before, all functionality you need to modify is within `submission.py`.
# 3.   Remember to execute all code cells sequentially, not just those you’ve edited, to ensure your code runs properly.
# 4.   Please cite any external sources you use to complete this assignment in your written responses.
# 5.   Before starting your work, please review <a href="https://s3.amazonaws.com/ecornell/global/eCornellPlagiarismPolicy.pdf">eCornell's policy regarding plagiarism</a> (the presentation of someone else's work as your own without source credit).
#
# &nbsp;
#
# **DONT's:**
#
#
# 1.   DO NOT change the names of any provided functions, classes, or variables within the existing code cells, as this will interfere with grading.
# 2.   DO NOT delete any provided code/imports.
#
# &nbsp;
#
# ---
#
# ***NOTE:***
#
# *You can resubmit your work as many times as necessary before the submission deadline. If you experience difficulty or have questions about this exercise, use the Ed discussion board to engage with your peers or seek assistance from the TAs.*

# %% [markdown]
# # Part 0: Install Dependencies, Set up Colab

# %%
# core
import os
import sys
import random
from itertools import count

# gym and rendering
import numpy as np
import torch
import gymnasium as gym
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import Image as ImageWidget

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("mps")
print(f"using device {device}!")
# Out:
# using device mps!

# %%
# Mount your Google Drive; this allows the runtime environment to see/edit your submission code.
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
# NOTE: Make sure your path does NOT include a '/' at the end!
#base_dir = "/content/gdrive/MyDrive/PATH-TO-ASSIGNMENT-5-DIRECTORY"
base_dir = "."
sys.path.append(base_dir)

# This makes sure the submission module is reloaded whenever you make edits.
# %load_ext autoreload
# %aimport submission
# %autoreload 1
import submission

# %% [markdown]
# ## Taxi Game

# %% [markdown]
# In this part, you will train the agent to play a simple Taxi game using Q-learning.
#
# <center><img src="https://www.gymlibrary.dev/_images/taxi.gif"></center>

# %% [markdown]
# There are four designated locations in the grid world indicated by R(ed), G(reen), Y(ellow), and B(lue). When the episode starts, the taxi starts off at a random square and the passenger is at a random location. The taxi drives to the passenger’s location, picks up the passenger, drives to the passenger’s destination (another one of the four specified locations), and then drops off the passenger. Once the passenger is dropped off, the episode ends.
#
# There are 6 discrete deterministic actions:
#
# $\mathcal{A}=\left\{\begin{align}
# &0, \text{ move south}\notag\\
# &1, \text{ move north}\notag\\
# &2, \text{ move east}\notag\\
# &3, \text{ move west}\notag\\
# &4, \text{ pick up passenger}\notag\\
# &5, \text{ drop off passenger}\notag\\
# \end{align}\right.$
#
# There are $500$ discrete states since there are $25$ taxi positions, $5$ possible locations of the passenger (including the case when the passenger is in the taxi), and $4$ destination locations.
#
# You can read the [full documentation](https://www.gymlibrary.dev/environments/toy_text/taxi/) for this environment set up.

# %% [markdown]
# Throughout this assignment, we will ask you to generate .gifs to showcase the policies you train.

# %%
def save_frames_as_video(frames, filename="output", fps=10):
    """Saves a list of frames as individual images and a GIF animation."""
    if not ".gif" in filename:
        filename += ".gif"
    
    pil_images = []
    for frame in frames:
        img_array = np.array(frame)
        pil_img = Image.fromarray(img_array)
        pil_images.append(pil_img)

    pil_images[0].save(
        filename,
        save_all=True,
        append_images=pil_images[1:],
        duration=int(1000 / fps),
        loop=0
    )

    print(f"Saved {len(frames)} individual frames to {filename}")

# %% [markdown]
# ## Taxi Visualization
#
# We will begin by visualizing a random policy for the taxi environment. Update the `video_path` as needed. All generated gifs should be uploaded along with notebook.

# %%
env = gym.make('Taxi-v4', render_mode = 'rgb_array')

frames = []
state, _ = env.reset(seed=random.randint(0,500))
frames.append(env.render())

for i in range(100):
    action = env.action_space.sample()
    state, reward, done, _, _ = env.step(action)
    frames.append(env.render())
    if done: break

save_frames_as_video(frames, gifname:=f"{base_dir}/taxi_random.gif", fps=10)

env.close()

ImageWidget(gifname)
# Out:
# Saved 101 individual frames to ./taxi_random.gif

# %% [markdown]
# # Part 1: Tabular Q-Learning (20 pts)

# %% [markdown]
# ## Q-Learning Background
#
# Imagine you're playing a game where each move $a$ (action) you make in a specific situation $s$ (state) gives you a certain immediate reward $r(s,a)$ and also may bring you to a new future state $s'$. If you want to play optimally, you need an "oracle" to evaluate how your decision now impacts the sequence of your future rewards. Then you could just listen to the oracle, picking the action which maximizes your future rewards at every state.
#
# We call this oracle $Q^\bigstar(s, a)$. It measures the expected long-term return if you pick action $a$ in state $s$ and then continue making optimal decisions afterward. If you had access to this "perfect knowledge," your policy $\pi$ is straightforward:
#
# $$\pi^\bigstar(s) = \underset{a}{\text{argmax}}\left[Q^\bigstar(s, a)\right]$$
#
# In other words, each turn simply choose the action that maximizes your expected future rewards.
#
# In reality, you don't know everything about the environment you're in, so $Q^\bigstar$ is inaccessible. The key insight behind Q-learning is that even without full knowledge of the world, you can still learn good estimates of these optimal Q-values with *experience*.

# %% [markdown]
# ### How to Q-Learn
#
# Tabular Q-learning uses a massive table to represent the Q-function: $\mathbb{R}^{\text{States}\times \text{Actions}}$. The table can be initialized with random or zero estimates, but each entry will be the estimate for how good each action is in each state. Every time you take an action and observe what happens, you can update your estimates in the table and gradually get closer to the true $Q^\star$ values.
#
# We can make such an update because Q-learning leverages an important relationship known as the **Bellman Equation**, which says that the value of a state-action pair $(s,a)$ under a policy $\pi$ can be expressed as:
#
# $$Q^\pi(s, a) = r + \gamma Q^\pi(s', \pi(s'))$$
#
# This means that the value of taking action $a$ in state $s$ under some policy $\pi$ equals the immediate reward $r$ plus a discounted estimate of future returns (the Q-value of the next state-action pair).
#
# Because your estimates are initially imperfect, you’ll see discrepancies between your current estimate and the reality you observe. This difference is called the **Temporal Difference (TD) error** $\delta$, and it's the core signal which we can use to drive Q-learning updates:
#
# $$\delta = \underset{\text{new target estimate}}{\underbrace{\left(r + \gamma \max_{a'} Q(s', a')\right)}}\ - \underset{\text{current estimate}}{\underbrace{Q(s, a)}}$$
#
# * If $\delta$ is positive, your action was worse than expected—*you should increase the Q-value*.
# * If $\delta$ is negative, your action was better than expected—*you should decrease the Q-value*.
#
# Take time to justify this to yourself.

# %% [markdown]
# ### The Q-learning Update Rule
#
# This intuition leads to the main update rule in Q-learning. Given an experience tuple $(s,a,r,s')$, we make the following update:
#
# $$Q(s, a) \leftarrow Q(s, a) + \alpha \left(\underset{\text{temporal difference error},\ \delta}{\underbrace{r + \gamma \max_{a'} Q(s', a') - Q(s, a)}}\right)$$
#
# Rearranging, we can get to the following update rule:
#
# $$Q(s, a) \leftarrow (1-\alpha)Q(s, a) + \alpha \left(r + \gamma \max_{a'} Q(s', a')\right)$$
#
# Where:
# * $\alpha$ is the learning rate
# * $\gamma$ is the discount factor

# %% [markdown]
# ### Convergence and Optimality
#
# Over many experiences, this simple rule ensures your Q-values become increasingly accurate approximations of $Q^\bigstar$. Once your Q-values stabilize (or "converge"), you have essentially found the optimal Q-function:
#
# $$Q(s,a)\approx Q^\bigstar(s,a), \forall s,a$$
#
# While this *does* imply $\underset{a}{\max} Q(s,a) \approx \underset{a}{\max} Q^\bigstar(s,a)$, do note that we cannot guarantee that $\underset{a}{\text{argmax}}\ Q(s,a) = \underset{a}{\text{argmax}}\ Q^\bigstar(s,a)$.
#
# Arbitrarily small errors in the Q-function may cause $\text{argmax}$ to pick an action which is ever-so-slightly preferred over the true optimal. So our max-policy $\pi(s):=\underset{a}{\text{argmax}}\ Q(s,a)$ could still be quite different from $\pi^\bigstar$. Fortunately, this scenario corresponds to multiple actions being equally valid (within some tolerance), and so we still expect $\pi$ to perform quite well.

# %% [markdown]
# ## Q-Learning Algorithm
# We present the Q-learning algorithm as follows:
#
# ![Screen Shot 2023-10-21 at 1.29.44 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### **TODO 1:** Implement `sample_action` in `submission.py`.
#
# When selecting an action, we'll employ the $\epsilon$-greedy strategy. With a probability of $1 - \epsilon$, the agent will choose the action that maximizes the Q-value for the current state based on the Q-table. With a probability of $\epsilon$, the agent will explore by selecting a random action.
#
# * You can obtain a random action using the following code:
#     ```python
#         a = env.action_space.sample()
#     ```
#
# * To get the optimal action from the Q-table, you'll need to find the action that corresponds to the highest Q-value for the current state.
#
# ### **TODO 2:** Implement `q_update` in `submission.py`.
#
# Use the equation in the algorithm provided above to update the Q table given some experience.
#
# ### **TODO 3:** Complete the `q_learning` method in `submission.py`.
# *Make sure to utilize the methods you implemented in the first two TODOs.*
#
# * To start an episode and obtain the initial state, you can use the following code:
#     ```python
#         observation, info = env.reset()
#     ```
#     * The `observation` variable will store the initial state of the environment.
#
# * To execute the chosen action and observe the outcome, you can use the following code:
#     ```python
#         s_next, r, terminated, truncated, info = env.step(a)
#     ```
#     * `s_next`: The state that the agent transitions to after taking action `a`.
#     * `r`: The reward associated with taking action `a` in the current state.
#     * `terminated`: A boolean value indicating whether the agent has reached a terminal state.
#     * `truncated`: A boolean value indicating whether the episode has been truncated due to conditions outside the scope of the Markov Decision Process (MDP), such as exceeding a time limit.
#
# * Make sure to update `rewards_per_episode` to keep track of the rewards obtained over the course of each trajectory.

# %% [markdown]
# If you need further information, you can refer to the following documentation:
#
# - `env.reset()`: [https://gymnasium.farama.org/api/env/#gymnasium.Env.reset](https://gymnasium.farama.org/api/env/#gymnasium.Env.reset)
# - `env.step()`: [https://gymnasium.farama.org/api/env/#gymnasium.Env.step](https://gymnasium.farama.org/api/env/#gymnasium.Env.step)
# - `env.action_space.sample()`: [https://gymnasium.farama.org/api/spaces/#gymnasium.spaces.space.Space.sample](https://gymnasium.farama.org/api/spaces/#gymnasium.spaces.space.Space.sample)

# %%
from submission import q_learning

# %%
# default prameters for Q-learning
alpha = .6
gamma = .9
epsilon = 0.05
epis = 1000

# initialize the environment
observation, info = env.reset()

# initialize the Q table
Q = np.zeros([env.observation_space.n, env.action_space.n])

# run Q-learning
Q, rewards_per_episode = q_learning(Q, env, epsilon, alpha, gamma, epis)
print("Final Q table\n", Q)
# Out:
# Episode 100/1000 | Average Reward (last 100 episodes): -224.81
# Episode 200/1000 | Average Reward (last 100 episodes): -50.19
# Episode 300/1000 | Average Reward (last 100 episodes): -12.52
# Episode 400/1000 | Average Reward (last 100 episodes): -1.78
# Episode 500/1000 | Average Reward (last 100 episodes): 2.45
# Episode 600/1000 | Average Reward (last 100 episodes): 3.45
# Episode 700/1000 | Average Reward (last 100 episodes): 5.09
# Episode 800/1000 | Average Reward (last 100 episodes): 5.40
# Episode 900/1000 | Average Reward (last 100 episodes): 5.77
# Episode 1000/1000 | Average Reward (last 100 episodes): 3.48
# Final Q table
#  [[ 0.          0.          0.          0.          0.          0.        ]
#  [-4.72724196 -4.93701793 -4.70660223 -4.93701793  1.62261467 -6.        ]
#  [ 3.84731323 -3.10130219 -3.02986053 -3.10130219  7.7147     -6.        ]
#  ...
#  [ 3.56443609  9.683      -2.66095978 -2.89073436 -6.         -6.        ]
#  [-4.27005198 -4.17163446 -4.27005198 -4.19381867 -6.         -6.        ]
#  [-1.164      -1.164      -1.164      12.456      -6.         -6.        ]]

# %%
# Plot the rewards per episode
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rewards_per_episode) + 1), rewards_per_episode)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Rewards per Episode')
plt.show()

# %% [markdown]
# ## Tabular Q-Learning Visualization
#
# Let's now visualize the learned policy for the taxi environment. Update the `video_path` as needed. All generated gifs should be uploaded along with notebook.

# %%
env = gym.make('Taxi-v4', render_mode = 'rgb_array')

frames = []
state, _ = env.reset(seed=random.randint(0,500))
frames.append(env.render())

for i in range(100):
    action = np.argmax(Q[state,:])
    state, reward, done, _, _ = env.step(action)
    frames.append(env.render())
    if done: break

save_frames_as_video(frames, gifname:=F"{base_dir}/taxi_q_learning.gif", fps=5)

env.close()

ImageWidget(gifname)
# Out:
# Saved 10 individual frames to ./taxi_q_learning.gif

# %% [markdown]
# ### **Q1**: How does the behavior of the Q-Learning agent compare to the random policy visualized previously? What policy does the agent appear to have learned? (5pts)
#
# Write 2-3 sentences in your responses document (.tex available on Canvas) which will be submitted alongside your assignment.

# %% [markdown]
# # Part 2: Deep Q-Networks (40 pts)

# %% [markdown]
# Deep Q-Networks (DQNs) extend the concept of Q-learning by using neural networks to approximate the Q-function, enabling it to handle large or continuous state spaces. Instead of maintaining a table of Q-values, a DQN learns a parameterized Q-function $Q(s, a; \theta) \approx Q^\star(s, a)$, where $\theta$ represents the weights of the neural network.
#
# The training process involves minimizing the temporal difference error between the predicted Q-value and the target Q-value, calculated using the Bellman equation. Note that this equation introduces a $\theta^-$, which represents the parameters of a separate target network (often a recent version of $\theta$). We update $\theta^-$ periodically to stabilize training.
#
# \begin{align}
# \underset{\text{target}}{\underbrace{Q^\pi(s, a)}} = \underset{\textit{true }\text{reward plus future }\textit{estimate}}{\underbrace{r + \gamma \max_{a'} Q^\pi(s', a'; \theta^-)}}
# \end{align}
#
# The loss function for training the DQN is just the mean squared error between the target network and our current network:
#
# \begin{align}
# \mathcal{L}(\theta)
# &= \underset{(s, a, r, s') \sim \mathscr{D}_\text{rb}}{\mathbb{\Large E}}\left[\left(Q^\pi(s, a) - Q(s, a; \theta)\right)^2\right]\\
# &= \underset{(s, a, r, s') \sim \mathscr{D}_\text{rb}}{\mathbb{\Large E}}\left[\left(r + \gamma \max_{a'}Q(s', a'; \theta^-) - Q(s, a; \theta)\right)^2\right]
# \end{align}
#
# Where $\mathscr{D}_\text{rb}$ is the replay buffer storing the agent's experience tuples.
#
# By minimizing this loss function using gradient descent, the DQN approximates the optimal Q-function, which can be used to derive our policy $\pi(s) = \underset{a}{\text{argmax}}\ Q(s, a; \theta)$.
#
# In the following sections, we will explore the implementation details of DQNs and their application to complex reinforcement learning tasks.

# %% [markdown]
# ## Cart Pole

# %% [markdown]
# You will be implementing the deep q-network to train the agent to play a slightly harder game, Cart Pole. In this game, a pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces in the left and right direction on the cart.
#
# Before you implement your deep Q-network, read this [documentation](https://gymnasium.farama.org/environments/classic_control/cart_pole/) to see what are the actions and states in this game.
#
# <center><img src="https://gymnasium.farama.org/_images/cart_pole.gif"></center>

# %% [markdown]
# ## Cartpole Visualization
#
# We will begin by visualizing a random policy for the cartpole environment. Update the `video_path` as needed. All generated gifs should be uploaded along with notebook.

# %%
env = gym.make('CartPole-v1', render_mode = 'rgb_array')

frames = []
done=False
state, _ = env.reset(seed=random.randint(0,500))
frames.append(env.render())

while not done:
    action = env.action_space.sample()
    state, reward, done, _, _ = env.step(action)
    frames.append(env.render())

save_frames_as_video(frames, gifname:=f"{base_dir}/cartpole_random.gif", fps=20)

env.close()

ImageWidget(gifname)
# Out:
# Saved 13 individual frames to ./cartpole_random.gif

# %% [markdown]
# ## 2.1: DQN Network (10 pts)

# %% [markdown]
# ### **TODO 4:** In the constructor (`__init__`), the network should be initialized with the following layers:
#
# 1. An input linear layer (`self.layer1`) that maps the state observations to 128 hidden units.
# 2. A hidden linear layer (`self.layer2`) with 128 input units and 128 output units.
# 3. An output linear layer (`self.layer3`) that maps the 128 hidden units to the number of actions.

# %% [markdown]
# ### **TODO 5:** In the `forward` method, the network should perform the following operations:
#
# ***NOTE:** When implementing ReLUs <u>use the functional interface</u> for this assignment. We have already imported torch.nn.functional as `F`, so be sure to call `F.relu()` whenever you need a ReLU in the forward pass instead of using defining `nn.ReLU()` layers in the init.*
#
# 1. Pass the input `x` through the first linear layer (`self.layer1`) followed by a ReLU activation function.
# 2. Pass the result through the second linear layer (`self.layer2`) followed by another ReLU activation function.
# 3. Pass the result through the output linear layer (`self.layer3`).
# 4. Return the final output.

# %% [markdown]
# **Implement the `DQN` class in `submission.py`** and then import it below:

# %%
from submission import DQN

# %% [markdown]
# ## Transition and Experience Replay

# %% [markdown]
# Here we provide you the Transition class, which stores a transition from the current state to the next state by taking action a with the associated reward r. The ReplayMemory stores all the transitions that the action has experienced, aka memory. Read the code and comment and make sure you are understand the attributes and methods. You will need to use some of them.

# %%
# Do not modify
class Transition(object):
  def __init__(self, s, a, next_s, r):
    self.state = s
    self.action = a
    self.next_state = next_s
    self.reward = r


class ExperienceReplay(object):
    def __init__(self, capacity):

        # Capacity of the agent's memory, always an int
        self.cap = capacity
        # A list of Transition objects that represent the agent's experiences
        self.memory = []
        # Current position of the agent, 0 <= self.pos < len(self.memory)
        self.pos = 0


    def push(self, *args):
        """
        Push a transition to the agent's memory.
        """
        if len(self.memory) < self.cap:
            self.memory.append(None)
        self.memory[self.pos] = Transition(*args)
        self.pos = (self.pos + 1) % self.cap


    def sample(self, batch_size):
        """
        Uniformly random sample batch_size of Transitions
        """
        return random.sample(self.memory, batch_size)


    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ## 2.2: DQN Agent (20 pts)

# %% [markdown]
# Now you will implement the DQNAgent in `submission.py`. This DQNAgent class should store two neural networks, as mentioned in lecture:
#
# - a policy network that predicts the next action
# - a target network that predicts the target Q-value
#
# ### **TODO 6**: Implement the epsilon-greedy strategy with the `eps_threshold` in `select_action`
# - We will use a decayed $ϵ$-strategy this time. In particular, we use this formula to calculate the current $ϵ$ value:
# $$ϵ = ϵ_\text{end} + (ϵ_\text{start} - ϵ_\text{end})⋅\exp(-\frac{\text{# steps done}}{ϵ_\text{decay}})$$
# - If `sample` is greater than `eps_threshold`, choose the action with the highest Q-value according to the policy network (exploitation).
#   - Use the policy network to get the Q-values for the current state.
#   - Find the index of the action with the highest Q-value.
#   - Wrap the result in a tensor with shape (1, 1).
# - If `sample` is less than or equal to `eps_threshold`, choose a random action (exploration).
#   - Generate a random action tensor with shape (1, 1) and the appropriate device and data type.
# - When sampling an action, use `torch.no_grad` or an alternative way of disabling gradient computations --- we are simply gathering experiences, so we don't want to keep gradient information. Think of this just like the original tabular Q-learning algorithm; we don't need to know how we sampled an action, we just use the experience itself to update the Q-table.

# %% [markdown]
# ### **TODO 7**: Compute the target state-action values using the Bellman equation
#
# - The target state-action values are calculated as the sum of the immediate reward and the discounted maximum Q-value of the next state.
# - Use the Bellman equation to compute the target state-action values:
#   - $Q^\pi(s, a) = r + \gamma Q^\pi(s', \pi(s'))$
#   - `next_state_values` contains the maximum Q-values of the next states (already computed) with shape (batch_size,).
#   - `self.gamma` is the discount factor (scalar).
#   - `reward_batch` contains the immediate rewards for each transition in the batch with shape (batch_size,).
# - The resulting `expected_state_action_values` tensor should have shape (batch_size,).
#
#
# ***NOTE**: You should take time to read through the `get_values` method in DQNAgent to understand what it returns.*

# %% [markdown]
# ### **TODO 8:** Compute the loss between the predicted state-action values and the target state-action values using the SmoothL1Loss
#
# - Use the SmoothL1Loss criterion to compute the loss between the predicted state-action values (`state_action_values`) and the target state-action values (`expected_state_action_values`).
#     - `self.criterion` is already defined in the `DQNAGent.__init__`, so use this to compute the loss.
# - `state_action_values` has shape (batch_size, 1), while `expected_state_action_values` has shape (batch_size,).
# - Make sure that the dimensions of `expected_state_action_values` match `state_action_values` and that both are the shape you expect.
# - Assign the computed loss to the `loss` variable.

# %% [markdown]
# **Implement `DQNAgent` class in `submission.py`** then import it below:

# %%
from submission import DQNAgent

# %% [markdown]
# We provide the training loop for the DQN.

# %%
def train_dqn(agent, env, num_episodes, render=False):
    episode_durations = []

    for i_episode in range(num_episodes):
        # Initialize the environment and get its state
        state, info = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        episode_reward = 0

        for t in count():
            # Select action
            action = agent.select_action(state)

            # Perform the action and observe the next state and reward
            next_state, reward, terminated, truncated, _ = env.step(action.item())
            reward = torch.tensor([reward], device=device)
            episode_reward += reward.item()

            # Determine if the episode is done
            done = terminated or truncated

            if terminated:
                next_state = None
            else:
                next_state = torch.tensor(next_state, dtype=torch.float32, device=device).unsqueeze(0)

            # Store the transition in the replay buffer
            agent.memory.push(state, action, next_state, reward)

            # Move to the next state
            state = next_state

            # Perform one step of the optimization
            if len(agent.memory) >= agent.batch_size:
                agent.optimize_model()

            if done:
                episode_durations.append(t + 1)
                print(f"Episode {i_episode+1}/{num_episodes}, Reward: {episode_reward:.2f}, Duration: {t+1}")
                break

        # Update the target network
        if i_episode % agent.target_update == 0:
            agent.target_net.load_state_dict(agent.policy_net.state_dict())

    env.close()
    return episode_durations

# %% [markdown]
# ## 2.3 Training and Visualization (10 pts)

# %%
dqn_agent = DQNAgent(env, device)
train = train_dqn(dqn_agent, env, num_episodes=150, render=False)
# Out:
# Episode 1/150, Reward: 44.00, Duration: 44
# Episode 2/150, Reward: 15.00, Duration: 15
# Episode 3/150, Reward: 21.00, Duration: 21
# Episode 4/150, Reward: 20.00, Duration: 20
# Episode 5/150, Reward: 27.00, Duration: 27
# Episode 6/150, Reward: 21.00, Duration: 21
# Episode 7/150, Reward: 26.00, Duration: 26
# Episode 8/150, Reward: 12.00, Duration: 12
# Episode 9/150, Reward: 8.00, Duration: 8
# Episode 10/150, Reward: 11.00, Duration: 11
# Episode 11/150, Reward: 14.00, Duration: 14
# Episode 12/150, Reward: 14.00, Duration: 14
# Episode 13/150, Reward: 13.00, Duration: 13
# Episode 14/150, Reward: 31.00, Duration: 31
# Episode 15/150, Reward: 10.00, Duration: 10
# Episode 16/150, Reward: 10.00, Duration: 10
# Episode 17/150, Reward: 11.00, Duration: 11
# Episode 18/150, Reward: 12.00, Duration: 12
# Episode 19/150, Reward: 10.00, Duration: 10
# Episode 20/150, Reward: 13.00, Duration: 13
# Episode 21/150, Reward: 12.00, Duration: 12
# Episode 22/150, Reward: 25.00, Duration: 25
# Episode 23/150, Reward: 17.00, Duration: 17
# Episode 24/150, Reward: 13.00, Duration: 13
# Episode 25/150, Reward: 12.00, Duration: 12
# Episode 26/150, Reward: 21.00, Duration: 21
# Episode 27/150, Reward: 14.00, Duration: 14
# Episode 28/150, Reward: 9.00, Duration: 9
# Episode 29/150, Reward: 15.00, Duration: 15
# Episode 30/150, Reward: 11.00, Duration: 11
# Episode 31/150, Reward: 10.00, Duration: 10
# Episode 32/150, Reward: 22.00, Duration: 22
# Episode 33/150, Reward: 19.00, Duration: 19
# Episode 34/150, Reward: 14.00, Duration: 14
# Episode 35/150, Reward: 23.00, Duration: 23
# Episode 36/150, Reward: 10.00, Duration: 10
# Episode 37/150, Reward: 14.00, Duration: 14
# Episode 38/150, Reward: 38.00, Duration: 38
# Episode 39/150, Reward: 14.00, Duration: 14
# Episode 40/150, Reward: 17.00, Duration: 17
# Episode 41/150, Reward: 24.00, Duration: 24
# Episode 42/150, Reward: 42.00, Duration: 42
# Episode 43/150, Reward: 31.00, Duration: 31
# Episode 44/150, Reward: 66.00, Duration: 66
# Episode 45/150, Reward: 129.00, Duration: 129
# Episode 46/150, Reward: 46.00, Duration: 46
# Episode 47/150, Reward: 116.00, Duration: 116
# Episode 48/150, Reward: 73.00, Duration: 73
# Episode 49/150, Reward: 129.00, Duration: 129
# Episode 50/150, Reward: 94.00, Duration: 94
# Episode 51/150, Reward: 82.00, Duration: 82
# Episode 52/150, Reward: 110.00, Duration: 110
# Episode 53/150, Reward: 124.00, Duration: 124
# Episode 54/150, Reward: 121.00, Duration: 121
# Episode 55/150, Reward: 119.00, Duration: 119
# Episode 56/150, Reward: 311.00, Duration: 311
# Episode 57/150, Reward: 102.00, Duration: 102
# Episode 58/150, Reward: 117.00, Duration: 117
# Episode 59/150, Reward: 110.00, Duration: 110
# Episode 60/150, Reward: 94.00, Duration: 94
# Episode 61/150, Reward: 121.00, Duration: 121
# Episode 62/150, Reward: 112.00, Duration: 112
# Episode 63/150, Reward: 125.00, Duration: 125
# Episode 64/150, Reward: 110.00, Duration: 110
# Episode 65/150, Reward: 139.00, Duration: 139
# Episode 66/150, Reward: 156.00, Duration: 156
# Episode 67/150, Reward: 142.00, Duration: 142
# Episode 68/150, Reward: 144.00, Duration: 144
# Episode 69/150, Reward: 151.00, Duration: 151
# Episode 70/150, Reward: 164.00, Duration: 164
# Episode 71/150, Reward: 13.00, Duration: 13
# Episode 72/150, Reward: 185.00, Duration: 185
# Episode 73/150, Reward: 156.00, Duration: 156
# Episode 74/150, Reward: 152.00, Duration: 152
# Episode 75/150, Reward: 141.00, Duration: 141
# Episode 76/150, Reward: 151.00, Duration: 151
# Episode 77/150, Reward: 161.00, Duration: 161
# Episode 78/150, Reward: 159.00, Duration: 159
# Episode 79/150, Reward: 152.00, Duration: 152
# Episode 80/150, Reward: 170.00, Duration: 170
# Episode 81/150, Reward: 158.00, Duration: 158
# Episode 82/150, Reward: 154.00, Duration: 154
# Episode 83/150, Reward: 134.00, Duration: 134
# Episode 84/150, Reward: 164.00, Duration: 164
# Episode 85/150, Reward: 125.00, Duration: 125
# Episode 86/150, Reward: 156.00, Duration: 156
# Episode 87/150, Reward: 132.00, Duration: 132
# Episode 88/150, Reward: 137.00, Duration: 137
# Episode 89/150, Reward: 148.00, Duration: 148
# Episode 90/150, Reward: 144.00, Duration: 144
# Episode 91/150, Reward: 131.00, Duration: 131
# Episode 92/150, Reward: 196.00, Duration: 196
# Episode 93/150, Reward: 169.00, Duration: 169
# Episode 94/150, Reward: 156.00, Duration: 156
# Episode 95/150, Reward: 153.00, Duration: 153
# Episode 96/150, Reward: 149.00, Duration: 149
# Episode 97/150, Reward: 163.00, Duration: 163
# Episode 98/150, Reward: 82.00, Duration: 82
# Episode 99/150, Reward: 169.00, Duration: 169
# Episode 100/150, Reward: 145.00, Duration: 145
# Episode 101/150, Reward: 151.00, Duration: 151
# Episode 102/150, Reward: 33.00, Duration: 33
# Episode 103/150, Reward: 175.00, Duration: 175
# Episode 104/150, Reward: 301.00, Duration: 301
# Episode 105/150, Reward: 135.00, Duration: 135
# Episode 106/150, Reward: 199.00, Duration: 199
# Episode 107/150, Reward: 151.00, Duration: 151
# Episode 108/150, Reward: 128.00, Duration: 128
# Episode 109/150, Reward: 194.00, Duration: 194
# Episode 110/150, Reward: 101.00, Duration: 101
# Episode 111/150, Reward: 134.00, Duration: 134
# Episode 112/150, Reward: 161.00, Duration: 161
# Episode 113/150, Reward: 217.00, Duration: 217
# Episode 114/150, Reward: 251.00, Duration: 251
# Episode 115/150, Reward: 296.00, Duration: 296
# Episode 116/150, Reward: 276.00, Duration: 276
# Episode 117/150, Reward: 158.00, Duration: 158
# Episode 118/150, Reward: 207.00, Duration: 207
# Episode 119/150, Reward: 308.00, Duration: 308
# Episode 120/150, Reward: 327.00, Duration: 327
# Episode 121/150, Reward: 417.00, Duration: 417
# Episode 122/150, Reward: 222.00, Duration: 222
# Episode 123/150, Reward: 158.00, Duration: 158
# Episode 124/150, Reward: 356.00, Duration: 356
# Episode 125/150, Reward: 380.00, Duration: 380
# Episode 126/150, Reward: 327.00, Duration: 327
# Episode 127/150, Reward: 216.00, Duration: 216
# Episode 128/150, Reward: 500.00, Duration: 500
# Episode 129/150, Reward: 500.00, Duration: 500
# Episode 130/150, Reward: 452.00, Duration: 452
# Episode 131/150, Reward: 108.00, Duration: 108
# Episode 132/150, Reward: 112.00, Duration: 112
# Episode 133/150, Reward: 29.00, Duration: 29
# Episode 134/150, Reward: 310.00, Duration: 310
# Episode 135/150, Reward: 368.00, Duration: 368
# Episode 136/150, Reward: 500.00, Duration: 500
# Episode 137/150, Reward: 478.00, Duration: 478
# Episode 138/150, Reward: 500.00, Duration: 500
# Episode 139/150, Reward: 500.00, Duration: 500
# Episode 140/150, Reward: 337.00, Duration: 337
# Episode 141/150, Reward: 392.00, Duration: 392
# Episode 142/150, Reward: 236.00, Duration: 236
# Episode 143/150, Reward: 332.00, Duration: 332
# Episode 144/150, Reward: 480.00, Duration: 480
# Episode 145/150, Reward: 370.00, Duration: 370
# Episode 146/150, Reward: 193.00, Duration: 193
# Episode 147/150, Reward: 249.00, Duration: 249
# Episode 148/150, Reward: 384.00, Duration: 384
# Episode 149/150, Reward: 270.00, Duration: 270
# Episode 150/150, Reward: 273.00, Duration: 273

# %%
# Plot the rewards per episode
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train) + 1), train)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Rewards per Episode')
plt.show()

# %% [markdown]
# ## Cartpole DQN Visualization
#
# We visualize the DQN policy for the cartpole environment. Update the `video_path` as needed. All generated gifs should be uploaded along with notebook.

# %%
env = gym.make('CartPole-v1', render_mode = 'rgb_array')

frames = []
done=False
state, _ = env.reset(seed=random.randint(0,500))
frames.append(env.render())

while not done:
    torch_state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    action = dqn_agent.select_action(torch_state).item()
    state, reward, done, _, _ = env.step(action)
    frames.append(env.render())

save_frames_as_video(frames, gifname:=f"{base_dir}/cartpole_dqn.gif", fps=20)

env.close()

ImageWidget(gifname)
# Out:
# Saved 4359 individual frames to ./cartpole_dqn.gif

# %% [markdown]
# ### **Q2**: How does the behavior of the DQN agent compare to the random policy visualized previously? What policy does the DQN agent appear to have learned? (5 pts)
#
# Answer with 2-3 sentences in your response document.

# %% [markdown]
# # Part 3: Policy Gradient (40 pts)

# %% [markdown]
# Now, we want to train the agent using the Reinforce algorithm to play the same game CartPole. Here is the algorithm we presented in lecture: ![Screen Shot 2023-11-04 at 11.07.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.1 The Policy Network (10 pts)

# %% [markdown]
# Now you will implement a policy gradient method in `submission.py` by implementing `PolicyNetwork`.
#
# ### **TODO 9:** In the constructor (`__init__`), the network should be initialized with the following layers:
#
# 1. An input linear layer (`self.fc1`) that maps the observation features to 128 hidden units.
#     - Apply `F.relu()` on the output of this layer before the next layer in the forward pass.
# 2. A hidden linear layer (`self.fc2`) that maps the 128 hidden units to the number of actions.
# 3. A Softmax activation function (`self.softmax`) for the output layer.
#
#
# The constructor should take the following arguments:
#
# - `number_observation_features` (int): The number of features in the observation space.
# - `number_actions` (int): The number of possible actions.

# %% [markdown]
# ### **TODO 10:** In the `forward` method, the network should take in an observation of the current state of the environment and output a distribution of scores per action.
#
# 1. Pass the input tensor `x` through the input linear layer (`self.fc1`).
#     - You can assume that `x` is not batched and just has shape (observation_dim,)
# 2. Apply the ReLU activation function to the output of the input layer.
# 3. Pass the result through the hidden linear layer (`self.fc2`).
# 4. Apply the Softmax activation function to the output of the hidden layer.
# 5. Return the final output tensor with scores per action.

# %% [markdown]
# **Implement `PolicyNetwork` class in `submission.py`** then run below to import it:

# %%
from submission import PolicyNetwork

# %% [markdown]
# ## 3.2 The Reinforce Agent (15 pts)

# %% [markdown]
# Finish the implementation of the class ReinforceAgent in `submission.py`.
#
# ### **TODO 11:** The `choose_action` method of the agent should perform the following steps:
# 1. Process the current state through the policy model to get the action probabilities.
# 2. Create a categorical distribution with the action probabilities.
#     - ***NOTE**: We have imported `Categorical` from `torch.distributions` for you.*
# 3. Sample an action from the distribution, representing the chosen action.
# 4. Compute the log probability of the sampled action, which is used for training the policy.

# %% [markdown]
# ### **TODO 12:** The `calculate_reinforce_loss` method in the agent should:
# 1. Subtract the mean from the returns to obtain a quantity known as the advantage.
# 2. Multiply the negative log probabilities with the advantage to obtain the loss for each action.
# 3. Return the mean of the loss across actions.

# %% [markdown]
# ### **TODO 13:** Implement the `calculate_discounted_returns` method.
#
# As a reminder, the cumulative discounted return at timestep $i$ is given as:
#
# \begin{equation*}
# \sum_{t=i}^{T} \gamma^{t-i} R(s_t, a_t)
# \end{equation*}
# where:
#
# - $\gamma \in [0, 1]$: Discount factor that balances immediate and future rewards.
# - $R(s_t, a_t)$: Return obtained from the environment at time step $t$ for taking action $a_t$ in state $s_t$.
#
# For numerical stability reasons, **and to please the autograder**, pay attention to the following as you implement this method:
#
# * By definition, for each timestep $i$ the cumulative discounted returns sums up discounted returns from timestep $i$ to timestep $T$. This involves many repetitive calculations, when computed in increasing order of timesteps.
# * Is there a way for you to reuse the repetitive calculations??
# * Specifically, think of iterate over the episode rewards in *reverse order* and make use of the values you have already computed.
# * In the reverse order, you start with an undiscounted reward $(\gamma^{T-T}*reward = \gamma^0* reward)$
# * An easy recursive/iterative way to evaluate the cumulative reward should emerge if you start by using this undiscounted reward.
# * Make sure that the first timestep $(t=0)$ corresponds to the beginning of the list.
#
# These discounted returns will be used in the training process to update the agent's policy network and encourage it to make decisions that maximize future cumulative discounted rewards.

# %% [markdown]
# **Implement `ReinforceAgent` class in `submission.py`** then import it below:

# %%
from submission import ReinforceAgent, calculate_discounted_returns

# %% [markdown]
# ## 3.3 Reinforce Training (5 pts)

# %% [markdown]
# Now let's train our Reinforce Agent.

# %%
def train_reinforce(agent, env, num_steps=50, num_episodes_per_update=5, gamma=0.98):
    episode_durations = []

    for step in range(num_steps):
        batch_log_probability_actions = []
        batch_returns = []

        for _ in range(num_episodes_per_update):
            episode_log_probability_actions = []
            episode_rewards = []

            episode_reward = 0
            state, _ = env.reset()

            for t in count():
                s = torch.from_numpy(state)
                action, log_probability_action = agent.choose_action(s)

                next_state, reward, terminated, truncated, info = env.step(action)
                episode_reward += reward

                episode_rewards.append(reward)
                episode_log_probability_actions.append(log_probability_action)

                done = terminated or truncated
                if done:
                    episode_durations.append(t + 1)
                    print(f"Step {step+1}/{num_steps}, Episode Reward: {episode_reward:.2f}, Duration: {t+1}")
                    break

                state = next_state

            discounted_returns = calculate_discounted_returns(episode_rewards, gamma)

            batch_log_probability_actions.append(episode_log_probability_actions)
            batch_returns.append(discounted_returns)

        batch_log_probability_actions = torch.cat([torch.stack(episode_log_probs) for episode_log_probs in batch_log_probability_actions])
        batch_returns = torch.tensor(sum(batch_returns, []), dtype=torch.float32)

        epoch_loss = agent.calculate_reinforce_loss(
            batch_log_probability_actions,
            batch_returns
        )

        epoch_loss.backward()
        agent.optimizer.step()
        agent.optimizer.zero_grad()

    env.close()
    return episode_durations

# %% [markdown]
# ## 3.4 Reinforce Visualization (5 pts)

# %%
env = gym.make('CartPole-v1', render_mode='rgb_array')
reinforce_agent = ReinforceAgent(env)
train = train_reinforce(reinforce_agent, env, num_steps=300)
# Out:
# Step 1/300, Episode Reward: 39.00, Duration: 39
# Step 1/300, Episode Reward: 9.00, Duration: 9
# Step 1/300, Episode Reward: 32.00, Duration: 32
# Step 1/300, Episode Reward: 24.00, Duration: 24
# Step 1/300, Episode Reward: 19.00, Duration: 19
# Step 2/300, Episode Reward: 13.00, Duration: 13
# Step 2/300, Episode Reward: 11.00, Duration: 11
# Step 2/300, Episode Reward: 18.00, Duration: 18
# Step 2/300, Episode Reward: 27.00, Duration: 27
# Step 2/300, Episode Reward: 13.00, Duration: 13
# Step 3/300, Episode Reward: 21.00, Duration: 21
# Step 3/300, Episode Reward: 74.00, Duration: 74
# Step 3/300, Episode Reward: 13.00, Duration: 13
# Step 3/300, Episode Reward: 11.00, Duration: 11
# Step 3/300, Episode Reward: 22.00, Duration: 22
# Step 4/300, Episode Reward: 45.00, Duration: 45
# Step 4/300, Episode Reward: 15.00, Duration: 15
# Step 4/300, Episode Reward: 26.00, Duration: 26
# Step 4/300, Episode Reward: 22.00, Duration: 22
# Step 4/300, Episode Reward: 23.00, Duration: 23
# Step 5/300, Episode Reward: 14.00, Duration: 14
# Step 5/300, Episode Reward: 24.00, Duration: 24
# Step 5/300, Episode Reward: 16.00, Duration: 16
# Step 5/300, Episode Reward: 16.00, Duration: 16
# Step 5/300, Episode Reward: 14.00, Duration: 14
# Step 6/300, Episode Reward: 25.00, Duration: 25
# Step 6/300, Episode Reward: 24.00, Duration: 24
# Step 6/300, Episode Reward: 41.00, Duration: 41
# Step 6/300, Episode Reward: 17.00, Duration: 17
# Step 6/300, Episode Reward: 11.00, Duration: 11
# Step 7/300, Episode Reward: 25.00, Duration: 25
# Step 7/300, Episode Reward: 21.00, Duration: 21
# Step 7/300, Episode Reward: 13.00, Duration: 13
# Step 7/300, Episode Reward: 12.00, Duration: 12
# Step 7/300, Episode Reward: 50.00, Duration: 50
# Step 8/300, Episode Reward: 34.00, Duration: 34
# Step 8/300, Episode Reward: 19.00, Duration: 19
# Step 8/300, Episode Reward: 10.00, Duration: 10
# Step 8/300, Episode Reward: 47.00, Duration: 47
# Step 8/300, Episode Reward: 26.00, Duration: 26
# Step 9/300, Episode Reward: 15.00, Duration: 15
# Step 9/300, Episode Reward: 11.00, Duration: 11
# Step 9/300, Episode Reward: 18.00, Duration: 18
# Step 9/300, Episode Reward: 15.00, Duration: 15
# Step 9/300, Episode Reward: 29.00, Duration: 29
# Step 10/300, Episode Reward: 14.00, Duration: 14
# Step 10/300, Episode Reward: 19.00, Duration: 19
# Step 10/300, Episode Reward: 20.00, Duration: 20
# Step 10/300, Episode Reward: 22.00, Duration: 22
# Step 10/300, Episode Reward: 10.00, Duration: 10
# Step 11/300, Episode Reward: 9.00, Duration: 9
# Step 11/300, Episode Reward: 26.00, Duration: 26
# Step 11/300, Episode Reward: 12.00, Duration: 12
# Step 11/300, Episode Reward: 11.00, Duration: 11
# Step 11/300, Episode Reward: 16.00, Duration: 16
# Step 12/300, Episode Reward: 25.00, Duration: 25
# Step 12/300, Episode Reward: 25.00, Duration: 25
# Step 12/300, Episode Reward: 10.00, Duration: 10
# Step 12/300, Episode Reward: 20.00, Duration: 20
# Step 12/300, Episode Reward: 25.00, Duration: 25
# Step 13/300, Episode Reward: 33.00, Duration: 33
# Step 13/300, Episode Reward: 20.00, Duration: 20
# Step 13/300, Episode Reward: 13.00, Duration: 13
# Step 13/300, Episode Reward: 41.00, Duration: 41
# Step 13/300, Episode Reward: 11.00, Duration: 11
# Step 14/300, Episode Reward: 17.00, Duration: 17
# Step 14/300, Episode Reward: 26.00, Duration: 26
# Step 14/300, Episode Reward: 11.00, Duration: 11
# Step 14/300, Episode Reward: 14.00, Duration: 14
# Step 14/300, Episode Reward: 18.00, Duration: 18
# Step 15/300, Episode Reward: 11.00, Duration: 11
# Step 15/300, Episode Reward: 18.00, Duration: 18
# Step 15/300, Episode Reward: 44.00, Duration: 44
# Step 15/300, Episode Reward: 13.00, Duration: 13
# Step 15/300, Episode Reward: 16.00, Duration: 16
# Step 16/300, Episode Reward: 23.00, Duration: 23
# Step 16/300, Episode Reward: 17.00, Duration: 17
# Step 16/300, Episode Reward: 11.00, Duration: 11
# Step 16/300, Episode Reward: 24.00, Duration: 24
# Step 16/300, Episode Reward: 10.00, Duration: 10
# Step 17/300, Episode Reward: 37.00, Duration: 37
# Step 17/300, Episode Reward: 18.00, Duration: 18
# Step 17/300, Episode Reward: 11.00, Duration: 11
# Step 17/300, Episode Reward: 22.00, Duration: 22
# Step 17/300, Episode Reward: 73.00, Duration: 73
# Step 18/300, Episode Reward: 10.00, Duration: 10
# Step 18/300, Episode Reward: 26.00, Duration: 26
# Step 18/300, Episode Reward: 16.00, Duration: 16
# Step 18/300, Episode Reward: 16.00, Duration: 16
# Step 18/300, Episode Reward: 16.00, Duration: 16
# Step 19/300, Episode Reward: 16.00, Duration: 16
# Step 19/300, Episode Reward: 35.00, Duration: 35
# Step 19/300, Episode Reward: 19.00, Duration: 19
# Step 19/300, Episode Reward: 12.00, Duration: 12
# Step 19/300, Episode Reward: 20.00, Duration: 20
# Step 20/300, Episode Reward: 36.00, Duration: 36
# Step 20/300, Episode Reward: 13.00, Duration: 13
# Step 20/300, Episode Reward: 34.00, Duration: 34
# Step 20/300, Episode Reward: 27.00, Duration: 27
# Step 20/300, Episode Reward: 50.00, Duration: 50
# Step 21/300, Episode Reward: 17.00, Duration: 17
# Step 21/300, Episode Reward: 16.00, Duration: 16
# Step 21/300, Episode Reward: 33.00, Duration: 33
# Step 21/300, Episode Reward: 15.00, Duration: 15
# Step 21/300, Episode Reward: 10.00, Duration: 10
# Step 22/300, Episode Reward: 37.00, Duration: 37
# Step 22/300, Episode Reward: 11.00, Duration: 11
# Step 22/300, Episode Reward: 20.00, Duration: 20
# Step 22/300, Episode Reward: 25.00, Duration: 25
# Step 22/300, Episode Reward: 20.00, Duration: 20
# Step 23/300, Episode Reward: 39.00, Duration: 39
# Step 23/300, Episode Reward: 23.00, Duration: 23
# Step 23/300, Episode Reward: 15.00, Duration: 15
# Step 23/300, Episode Reward: 14.00, Duration: 14
# Step 23/300, Episode Reward: 28.00, Duration: 28
# Step 24/300, Episode Reward: 13.00, Duration: 13
# Step 24/300, Episode Reward: 14.00, Duration: 14
# Step 24/300, Episode Reward: 22.00, Duration: 22
# Step 24/300, Episode Reward: 14.00, Duration: 14
# Step 24/300, Episode Reward: 27.00, Duration: 27
# Step 25/300, Episode Reward: 74.00, Duration: 74
# Step 25/300, Episode Reward: 23.00, Duration: 23
# Step 25/300, Episode Reward: 27.00, Duration: 27
# Step 25/300, Episode Reward: 12.00, Duration: 12
# Step 25/300, Episode Reward: 16.00, Duration: 16
# Step 26/300, Episode Reward: 36.00, Duration: 36
# Step 26/300, Episode Reward: 17.00, Duration: 17
# Step 26/300, Episode Reward: 17.00, Duration: 17
# Step 26/300, Episode Reward: 24.00, Duration: 24
# Step 26/300, Episode Reward: 30.00, Duration: 30
# Step 27/300, Episode Reward: 8.00, Duration: 8
# Step 27/300, Episode Reward: 40.00, Duration: 40
# Step 27/300, Episode Reward: 23.00, Duration: 23
# Step 27/300, Episode Reward: 77.00, Duration: 77
# Step 27/300, Episode Reward: 15.00, Duration: 15
# Step 28/300, Episode Reward: 16.00, Duration: 16
# Step 28/300, Episode Reward: 36.00, Duration: 36
# Step 28/300, Episode Reward: 13.00, Duration: 13
# Step 28/300, Episode Reward: 31.00, Duration: 31
# Step 28/300, Episode Reward: 44.00, Duration: 44
# Step 29/300, Episode Reward: 14.00, Duration: 14
# Step 29/300, Episode Reward: 27.00, Duration: 27
# Step 29/300, Episode Reward: 27.00, Duration: 27
# Step 29/300, Episode Reward: 16.00, Duration: 16
# Step 29/300, Episode Reward: 22.00, Duration: 22
# Step 30/300, Episode Reward: 21.00, Duration: 21
# Step 30/300, Episode Reward: 21.00, Duration: 21
# Step 30/300, Episode Reward: 23.00, Duration: 23
# Step 30/300, Episode Reward: 15.00, Duration: 15
# Step 30/300, Episode Reward: 74.00, Duration: 74
# Step 31/300, Episode Reward: 31.00, Duration: 31
# Step 31/300, Episode Reward: 22.00, Duration: 22
# Step 31/300, Episode Reward: 26.00, Duration: 26
# Step 31/300, Episode Reward: 17.00, Duration: 17
# Step 31/300, Episode Reward: 27.00, Duration: 27
# Step 32/300, Episode Reward: 50.00, Duration: 50
# Step 32/300, Episode Reward: 34.00, Duration: 34
# Step 32/300, Episode Reward: 36.00, Duration: 36
# Step 32/300, Episode Reward: 29.00, Duration: 29
# Step 32/300, Episode Reward: 14.00, Duration: 14
# Step 33/300, Episode Reward: 25.00, Duration: 25
# Step 33/300, Episode Reward: 12.00, Duration: 12
# Step 33/300, Episode Reward: 21.00, Duration: 21
# Step 33/300, Episode Reward: 24.00, Duration: 24
# Step 33/300, Episode Reward: 18.00, Duration: 18
# Step 34/300, Episode Reward: 26.00, Duration: 26
# Step 34/300, Episode Reward: 35.00, Duration: 35
# Step 34/300, Episode Reward: 37.00, Duration: 37
# Step 34/300, Episode Reward: 33.00, Duration: 33
# Step 34/300, Episode Reward: 22.00, Duration: 22
# Step 35/300, Episode Reward: 25.00, Duration: 25
# Step 35/300, Episode Reward: 18.00, Duration: 18
# Step 35/300, Episode Reward: 11.00, Duration: 11
# Step 35/300, Episode Reward: 34.00, Duration: 34
# Step 35/300, Episode Reward: 49.00, Duration: 49
# Step 36/300, Episode Reward: 16.00, Duration: 16
# Step 36/300, Episode Reward: 27.00, Duration: 27
# Step 36/300, Episode Reward: 26.00, Duration: 26
# Step 36/300, Episode Reward: 16.00, Duration: 16
# Step 36/300, Episode Reward: 30.00, Duration: 30
# Step 37/300, Episode Reward: 26.00, Duration: 26
# Step 37/300, Episode Reward: 20.00, Duration: 20
# Step 37/300, Episode Reward: 23.00, Duration: 23
# Step 37/300, Episode Reward: 20.00, Duration: 20
# Step 37/300, Episode Reward: 59.00, Duration: 59
# Step 38/300, Episode Reward: 21.00, Duration: 21
# Step 38/300, Episode Reward: 61.00, Duration: 61
# Step 38/300, Episode Reward: 13.00, Duration: 13
# Step 38/300, Episode Reward: 17.00, Duration: 17
# Step 38/300, Episode Reward: 21.00, Duration: 21
# Step 39/300, Episode Reward: 52.00, Duration: 52
# Step 39/300, Episode Reward: 21.00, Duration: 21
# Step 39/300, Episode Reward: 50.00, Duration: 50
# Step 39/300, Episode Reward: 14.00, Duration: 14
# Step 39/300, Episode Reward: 18.00, Duration: 18
# Step 40/300, Episode Reward: 57.00, Duration: 57
# Step 40/300, Episode Reward: 19.00, Duration: 19
# Step 40/300, Episode Reward: 25.00, Duration: 25
# Step 40/300, Episode Reward: 17.00, Duration: 17
# Step 40/300, Episode Reward: 80.00, Duration: 80
# Step 41/300, Episode Reward: 31.00, Duration: 31
# Step 41/300, Episode Reward: 26.00, Duration: 26
# Step 41/300, Episode Reward: 19.00, Duration: 19
# Step 41/300, Episode Reward: 26.00, Duration: 26
# Step 41/300, Episode Reward: 18.00, Duration: 18
# Step 42/300, Episode Reward: 25.00, Duration: 25
# Step 42/300, Episode Reward: 22.00, Duration: 22
# Step 42/300, Episode Reward: 21.00, Duration: 21
# Step 42/300, Episode Reward: 47.00, Duration: 47
# Step 42/300, Episode Reward: 19.00, Duration: 19
# Step 43/300, Episode Reward: 20.00, Duration: 20
# Step 43/300, Episode Reward: 17.00, Duration: 17
# Step 43/300, Episode Reward: 26.00, Duration: 26
# Step 43/300, Episode Reward: 15.00, Duration: 15
# Step 43/300, Episode Reward: 20.00, Duration: 20
# Step 44/300, Episode Reward: 28.00, Duration: 28
# Step 44/300, Episode Reward: 35.00, Duration: 35
# Step 44/300, Episode Reward: 54.00, Duration: 54
# Step 44/300, Episode Reward: 9.00, Duration: 9
# Step 44/300, Episode Reward: 31.00, Duration: 31
# Step 45/300, Episode Reward: 18.00, Duration: 18
# Step 45/300, Episode Reward: 28.00, Duration: 28
# Step 45/300, Episode Reward: 20.00, Duration: 20
# Step 45/300, Episode Reward: 21.00, Duration: 21
# Step 45/300, Episode Reward: 51.00, Duration: 51
# Step 46/300, Episode Reward: 53.00, Duration: 53
# Step 46/300, Episode Reward: 63.00, Duration: 63
# Step 46/300, Episode Reward: 18.00, Duration: 18
# Step 46/300, Episode Reward: 23.00, Duration: 23
# Step 46/300, Episode Reward: 34.00, Duration: 34
# Step 47/300, Episode Reward: 18.00, Duration: 18
# Step 47/300, Episode Reward: 50.00, Duration: 50
# Step 47/300, Episode Reward: 61.00, Duration: 61
# Step 47/300, Episode Reward: 19.00, Duration: 19
# Step 47/300, Episode Reward: 14.00, Duration: 14
# Step 48/300, Episode Reward: 14.00, Duration: 14
# Step 48/300, Episode Reward: 33.00, Duration: 33
# Step 48/300, Episode Reward: 19.00, Duration: 19
# Step 48/300, Episode Reward: 22.00, Duration: 22
# Step 48/300, Episode Reward: 20.00, Duration: 20
# Step 49/300, Episode Reward: 36.00, Duration: 36
# Step 49/300, Episode Reward: 13.00, Duration: 13
# Step 49/300, Episode Reward: 19.00, Duration: 19
# Step 49/300, Episode Reward: 25.00, Duration: 25
# Step 49/300, Episode Reward: 14.00, Duration: 14
# Step 50/300, Episode Reward: 29.00, Duration: 29
# Step 50/300, Episode Reward: 32.00, Duration: 32
# Step 50/300, Episode Reward: 13.00, Duration: 13
# Step 50/300, Episode Reward: 14.00, Duration: 14
# Step 50/300, Episode Reward: 25.00, Duration: 25
# Step 51/300, Episode Reward: 13.00, Duration: 13
# Step 51/300, Episode Reward: 77.00, Duration: 77
# Step 51/300, Episode Reward: 36.00, Duration: 36
# Step 51/300, Episode Reward: 23.00, Duration: 23
# Step 51/300, Episode Reward: 64.00, Duration: 64
# Step 52/300, Episode Reward: 31.00, Duration: 31
# Step 52/300, Episode Reward: 23.00, Duration: 23
# Step 52/300, Episode Reward: 20.00, Duration: 20
# Step 52/300, Episode Reward: 15.00, Duration: 15
# Step 52/300, Episode Reward: 22.00, Duration: 22
# Step 53/300, Episode Reward: 37.00, Duration: 37
# Step 53/300, Episode Reward: 24.00, Duration: 24
# Step 53/300, Episode Reward: 14.00, Duration: 14
# Step 53/300, Episode Reward: 77.00, Duration: 77
# Step 53/300, Episode Reward: 26.00, Duration: 26
# Step 54/300, Episode Reward: 65.00, Duration: 65
# Step 54/300, Episode Reward: 16.00, Duration: 16
# Step 54/300, Episode Reward: 11.00, Duration: 11
# Step 54/300, Episode Reward: 24.00, Duration: 24
# Step 54/300, Episode Reward: 27.00, Duration: 27
# Step 55/300, Episode Reward: 26.00, Duration: 26
# Step 55/300, Episode Reward: 10.00, Duration: 10
# Step 55/300, Episode Reward: 19.00, Duration: 19
# Step 55/300, Episode Reward: 29.00, Duration: 29
# Step 55/300, Episode Reward: 34.00, Duration: 34
# Step 56/300, Episode Reward: 40.00, Duration: 40
# Step 56/300, Episode Reward: 15.00, Duration: 15
# Step 56/300, Episode Reward: 27.00, Duration: 27
# Step 56/300, Episode Reward: 21.00, Duration: 21
# Step 56/300, Episode Reward: 36.00, Duration: 36
# Step 57/300, Episode Reward: 22.00, Duration: 22
# Step 57/300, Episode Reward: 44.00, Duration: 44
# Step 57/300, Episode Reward: 22.00, Duration: 22
# Step 57/300, Episode Reward: 15.00, Duration: 15
# Step 57/300, Episode Reward: 22.00, Duration: 22
# Step 58/300, Episode Reward: 57.00, Duration: 57
# Step 58/300, Episode Reward: 14.00, Duration: 14
# Step 58/300, Episode Reward: 19.00, Duration: 19
# Step 58/300, Episode Reward: 33.00, Duration: 33
# Step 58/300, Episode Reward: 35.00, Duration: 35
# Step 59/300, Episode Reward: 68.00, Duration: 68
# Step 59/300, Episode Reward: 39.00, Duration: 39
# Step 59/300, Episode Reward: 26.00, Duration: 26
# Step 59/300, Episode Reward: 22.00, Duration: 22
# Step 59/300, Episode Reward: 32.00, Duration: 32
# Step 60/300, Episode Reward: 47.00, Duration: 47
# Step 60/300, Episode Reward: 43.00, Duration: 43
# Step 60/300, Episode Reward: 41.00, Duration: 41
# Step 60/300, Episode Reward: 45.00, Duration: 45
# Step 60/300, Episode Reward: 17.00, Duration: 17
# Step 61/300, Episode Reward: 50.00, Duration: 50
# Step 61/300, Episode Reward: 43.00, Duration: 43
# Step 61/300, Episode Reward: 33.00, Duration: 33
# Step 61/300, Episode Reward: 12.00, Duration: 12
# Step 61/300, Episode Reward: 23.00, Duration: 23
# Step 62/300, Episode Reward: 56.00, Duration: 56
# Step 62/300, Episode Reward: 22.00, Duration: 22
# Step 62/300, Episode Reward: 18.00, Duration: 18
# Step 62/300, Episode Reward: 25.00, Duration: 25
# Step 62/300, Episode Reward: 31.00, Duration: 31
# Step 63/300, Episode Reward: 55.00, Duration: 55
# Step 63/300, Episode Reward: 35.00, Duration: 35
# Step 63/300, Episode Reward: 21.00, Duration: 21
# Step 63/300, Episode Reward: 35.00, Duration: 35
# Step 63/300, Episode Reward: 37.00, Duration: 37
# Step 64/300, Episode Reward: 35.00, Duration: 35
# Step 64/300, Episode Reward: 38.00, Duration: 38
# Step 64/300, Episode Reward: 54.00, Duration: 54
# Step 64/300, Episode Reward: 146.00, Duration: 146
# Step 64/300, Episode Reward: 25.00, Duration: 25
# Step 65/300, Episode Reward: 20.00, Duration: 20
# Step 65/300, Episode Reward: 21.00, Duration: 21
# Step 65/300, Episode Reward: 22.00, Duration: 22
# Step 65/300, Episode Reward: 32.00, Duration: 32
# Step 65/300, Episode Reward: 66.00, Duration: 66
# Step 66/300, Episode Reward: 39.00, Duration: 39
# Step 66/300, Episode Reward: 27.00, Duration: 27
# Step 66/300, Episode Reward: 37.00, Duration: 37
# Step 66/300, Episode Reward: 30.00, Duration: 30
# Step 66/300, Episode Reward: 49.00, Duration: 49
# Step 67/300, Episode Reward: 44.00, Duration: 44
# Step 67/300, Episode Reward: 21.00, Duration: 21
# Step 67/300, Episode Reward: 37.00, Duration: 37
# Step 67/300, Episode Reward: 20.00, Duration: 20
# Step 67/300, Episode Reward: 45.00, Duration: 45
# Step 68/300, Episode Reward: 18.00, Duration: 18
# Step 68/300, Episode Reward: 38.00, Duration: 38
# Step 68/300, Episode Reward: 40.00, Duration: 40
# Step 68/300, Episode Reward: 19.00, Duration: 19
# Step 68/300, Episode Reward: 29.00, Duration: 29
# Step 69/300, Episode Reward: 34.00, Duration: 34
# Step 69/300, Episode Reward: 32.00, Duration: 32
# Step 69/300, Episode Reward: 32.00, Duration: 32
# Step 69/300, Episode Reward: 12.00, Duration: 12
# Step 69/300, Episode Reward: 27.00, Duration: 27
# Step 70/300, Episode Reward: 18.00, Duration: 18
# Step 70/300, Episode Reward: 32.00, Duration: 32
# Step 70/300, Episode Reward: 30.00, Duration: 30
# Step 70/300, Episode Reward: 32.00, Duration: 32
# Step 70/300, Episode Reward: 41.00, Duration: 41
# Step 71/300, Episode Reward: 72.00, Duration: 72
# Step 71/300, Episode Reward: 21.00, Duration: 21
# Step 71/300, Episode Reward: 45.00, Duration: 45
# Step 71/300, Episode Reward: 36.00, Duration: 36
# Step 71/300, Episode Reward: 10.00, Duration: 10
# Step 72/300, Episode Reward: 55.00, Duration: 55
# Step 72/300, Episode Reward: 16.00, Duration: 16
# Step 72/300, Episode Reward: 59.00, Duration: 59
# Step 72/300, Episode Reward: 63.00, Duration: 63
# Step 72/300, Episode Reward: 31.00, Duration: 31
# Step 73/300, Episode Reward: 18.00, Duration: 18
# Step 73/300, Episode Reward: 27.00, Duration: 27
# Step 73/300, Episode Reward: 30.00, Duration: 30
# Step 73/300, Episode Reward: 34.00, Duration: 34
# Step 73/300, Episode Reward: 21.00, Duration: 21
# Step 74/300, Episode Reward: 54.00, Duration: 54
# Step 74/300, Episode Reward: 19.00, Duration: 19
# Step 74/300, Episode Reward: 43.00, Duration: 43
# Step 74/300, Episode Reward: 38.00, Duration: 38
# Step 74/300, Episode Reward: 61.00, Duration: 61
# Step 75/300, Episode Reward: 52.00, Duration: 52
# Step 75/300, Episode Reward: 67.00, Duration: 67
# Step 75/300, Episode Reward: 27.00, Duration: 27
# Step 75/300, Episode Reward: 23.00, Duration: 23
# Step 75/300, Episode Reward: 19.00, Duration: 19
# Step 76/300, Episode Reward: 33.00, Duration: 33
# Step 76/300, Episode Reward: 46.00, Duration: 46
# Step 76/300, Episode Reward: 31.00, Duration: 31
# Step 76/300, Episode Reward: 36.00, Duration: 36
# Step 76/300, Episode Reward: 46.00, Duration: 46
# Step 77/300, Episode Reward: 59.00, Duration: 59
# Step 77/300, Episode Reward: 52.00, Duration: 52
# Step 77/300, Episode Reward: 42.00, Duration: 42
# Step 77/300, Episode Reward: 62.00, Duration: 62
# Step 77/300, Episode Reward: 63.00, Duration: 63
# Step 78/300, Episode Reward: 48.00, Duration: 48
# Step 78/300, Episode Reward: 34.00, Duration: 34
# Step 78/300, Episode Reward: 105.00, Duration: 105
# Step 78/300, Episode Reward: 12.00, Duration: 12
# Step 78/300, Episode Reward: 26.00, Duration: 26
# Step 79/300, Episode Reward: 59.00, Duration: 59
# Step 79/300, Episode Reward: 63.00, Duration: 63
# Step 79/300, Episode Reward: 35.00, Duration: 35
# Step 79/300, Episode Reward: 50.00, Duration: 50
# Step 79/300, Episode Reward: 31.00, Duration: 31
# Step 80/300, Episode Reward: 73.00, Duration: 73
# Step 80/300, Episode Reward: 36.00, Duration: 36
# Step 80/300, Episode Reward: 17.00, Duration: 17
# Step 80/300, Episode Reward: 100.00, Duration: 100
# Step 80/300, Episode Reward: 49.00, Duration: 49
# Step 81/300, Episode Reward: 35.00, Duration: 35
# Step 81/300, Episode Reward: 68.00, Duration: 68
# Step 81/300, Episode Reward: 54.00, Duration: 54
# Step 81/300, Episode Reward: 18.00, Duration: 18
# Step 81/300, Episode Reward: 92.00, Duration: 92
# Step 82/300, Episode Reward: 38.00, Duration: 38
# Step 82/300, Episode Reward: 58.00, Duration: 58
# Step 82/300, Episode Reward: 30.00, Duration: 30
# Step 82/300, Episode Reward: 30.00, Duration: 30
# Step 82/300, Episode Reward: 20.00, Duration: 20
# Step 83/300, Episode Reward: 61.00, Duration: 61
# Step 83/300, Episode Reward: 55.00, Duration: 55
# Step 83/300, Episode Reward: 30.00, Duration: 30
# Step 83/300, Episode Reward: 25.00, Duration: 25
# Step 83/300, Episode Reward: 18.00, Duration: 18
# Step 84/300, Episode Reward: 30.00, Duration: 30
# Step 84/300, Episode Reward: 26.00, Duration: 26
# Step 84/300, Episode Reward: 49.00, Duration: 49
# Step 84/300, Episode Reward: 38.00, Duration: 38
# Step 84/300, Episode Reward: 33.00, Duration: 33
# Step 85/300, Episode Reward: 63.00, Duration: 63
# Step 85/300, Episode Reward: 18.00, Duration: 18
# Step 85/300, Episode Reward: 63.00, Duration: 63
# Step 85/300, Episode Reward: 41.00, Duration: 41
# Step 85/300, Episode Reward: 30.00, Duration: 30
# Step 86/300, Episode Reward: 36.00, Duration: 36
# Step 86/300, Episode Reward: 42.00, Duration: 42
# Step 86/300, Episode Reward: 48.00, Duration: 48
# Step 86/300, Episode Reward: 29.00, Duration: 29
# Step 86/300, Episode Reward: 53.00, Duration: 53
# Step 87/300, Episode Reward: 65.00, Duration: 65
# Step 87/300, Episode Reward: 58.00, Duration: 58
# Step 87/300, Episode Reward: 58.00, Duration: 58
# Step 87/300, Episode Reward: 50.00, Duration: 50
# Step 87/300, Episode Reward: 49.00, Duration: 49
# Step 88/300, Episode Reward: 36.00, Duration: 36
# Step 88/300, Episode Reward: 46.00, Duration: 46
# Step 88/300, Episode Reward: 99.00, Duration: 99
# Step 88/300, Episode Reward: 46.00, Duration: 46
# Step 88/300, Episode Reward: 45.00, Duration: 45
# Step 89/300, Episode Reward: 28.00, Duration: 28
# Step 89/300, Episode Reward: 39.00, Duration: 39
# Step 89/300, Episode Reward: 41.00, Duration: 41
# Step 89/300, Episode Reward: 97.00, Duration: 97
# Step 89/300, Episode Reward: 48.00, Duration: 48
# Step 90/300, Episode Reward: 67.00, Duration: 67
# Step 90/300, Episode Reward: 50.00, Duration: 50
# Step 90/300, Episode Reward: 19.00, Duration: 19
# Step 90/300, Episode Reward: 22.00, Duration: 22
# Step 90/300, Episode Reward: 77.00, Duration: 77
# Step 91/300, Episode Reward: 99.00, Duration: 99
# Step 91/300, Episode Reward: 79.00, Duration: 79
# Step 91/300, Episode Reward: 70.00, Duration: 70
# Step 91/300, Episode Reward: 49.00, Duration: 49
# Step 91/300, Episode Reward: 29.00, Duration: 29
# Step 92/300, Episode Reward: 65.00, Duration: 65
# Step 92/300, Episode Reward: 63.00, Duration: 63
# Step 92/300, Episode Reward: 43.00, Duration: 43
# Step 92/300, Episode Reward: 27.00, Duration: 27
# Step 92/300, Episode Reward: 45.00, Duration: 45
# Step 93/300, Episode Reward: 56.00, Duration: 56
# Step 93/300, Episode Reward: 108.00, Duration: 108
# Step 93/300, Episode Reward: 65.00, Duration: 65
# Step 93/300, Episode Reward: 27.00, Duration: 27
# Step 93/300, Episode Reward: 24.00, Duration: 24
# Step 94/300, Episode Reward: 40.00, Duration: 40
# Step 94/300, Episode Reward: 39.00, Duration: 39
# Step 94/300, Episode Reward: 77.00, Duration: 77
# Step 94/300, Episode Reward: 44.00, Duration: 44
# Step 94/300, Episode Reward: 20.00, Duration: 20
# Step 95/300, Episode Reward: 135.00, Duration: 135
# Step 95/300, Episode Reward: 32.00, Duration: 32
# Step 95/300, Episode Reward: 42.00, Duration: 42
# Step 95/300, Episode Reward: 108.00, Duration: 108
# Step 95/300, Episode Reward: 80.00, Duration: 80
# Step 96/300, Episode Reward: 46.00, Duration: 46
# Step 96/300, Episode Reward: 39.00, Duration: 39
# Step 96/300, Episode Reward: 25.00, Duration: 25
# Step 96/300, Episode Reward: 17.00, Duration: 17
# Step 96/300, Episode Reward: 72.00, Duration: 72
# Step 97/300, Episode Reward: 24.00, Duration: 24
# Step 97/300, Episode Reward: 85.00, Duration: 85
# Step 97/300, Episode Reward: 32.00, Duration: 32
# Step 97/300, Episode Reward: 42.00, Duration: 42
# Step 97/300, Episode Reward: 24.00, Duration: 24
# Step 98/300, Episode Reward: 51.00, Duration: 51
# Step 98/300, Episode Reward: 64.00, Duration: 64
# Step 98/300, Episode Reward: 37.00, Duration: 37
# Step 98/300, Episode Reward: 36.00, Duration: 36
# Step 98/300, Episode Reward: 51.00, Duration: 51
# Step 99/300, Episode Reward: 40.00, Duration: 40
# Step 99/300, Episode Reward: 48.00, Duration: 48
# Step 99/300, Episode Reward: 36.00, Duration: 36
# Step 99/300, Episode Reward: 32.00, Duration: 32
# Step 99/300, Episode Reward: 27.00, Duration: 27
# Step 100/300, Episode Reward: 87.00, Duration: 87
# Step 100/300, Episode Reward: 24.00, Duration: 24
# Step 100/300, Episode Reward: 35.00, Duration: 35
# Step 100/300, Episode Reward: 33.00, Duration: 33
# Step 100/300, Episode Reward: 38.00, Duration: 38
# Step 101/300, Episode Reward: 15.00, Duration: 15
# Step 101/300, Episode Reward: 42.00, Duration: 42
# Step 101/300, Episode Reward: 60.00, Duration: 60
# Step 101/300, Episode Reward: 46.00, Duration: 46
# Step 101/300, Episode Reward: 76.00, Duration: 76
# Step 102/300, Episode Reward: 29.00, Duration: 29
# Step 102/300, Episode Reward: 37.00, Duration: 37
# Step 102/300, Episode Reward: 86.00, Duration: 86
# Step 102/300, Episode Reward: 27.00, Duration: 27
# Step 102/300, Episode Reward: 63.00, Duration: 63
# Step 103/300, Episode Reward: 36.00, Duration: 36
# Step 103/300, Episode Reward: 52.00, Duration: 52
# Step 103/300, Episode Reward: 71.00, Duration: 71
# Step 103/300, Episode Reward: 75.00, Duration: 75
# Step 103/300, Episode Reward: 53.00, Duration: 53
# Step 104/300, Episode Reward: 58.00, Duration: 58
# Step 104/300, Episode Reward: 44.00, Duration: 44
# Step 104/300, Episode Reward: 31.00, Duration: 31
# Step 104/300, Episode Reward: 55.00, Duration: 55
# Step 104/300, Episode Reward: 30.00, Duration: 30
# Step 105/300, Episode Reward: 72.00, Duration: 72
# Step 105/300, Episode Reward: 38.00, Duration: 38
# Step 105/300, Episode Reward: 19.00, Duration: 19
# Step 105/300, Episode Reward: 54.00, Duration: 54
# Step 105/300, Episode Reward: 67.00, Duration: 67
# Step 106/300, Episode Reward: 19.00, Duration: 19
# Step 106/300, Episode Reward: 85.00, Duration: 85
# Step 106/300, Episode Reward: 66.00, Duration: 66
# Step 106/300, Episode Reward: 41.00, Duration: 41
# Step 106/300, Episode Reward: 26.00, Duration: 26
# Step 107/300, Episode Reward: 96.00, Duration: 96
# Step 107/300, Episode Reward: 108.00, Duration: 108
# Step 107/300, Episode Reward: 37.00, Duration: 37
# Step 107/300, Episode Reward: 99.00, Duration: 99
# Step 107/300, Episode Reward: 58.00, Duration: 58
# Step 108/300, Episode Reward: 83.00, Duration: 83
# Step 108/300, Episode Reward: 41.00, Duration: 41
# Step 108/300, Episode Reward: 65.00, Duration: 65
# Step 108/300, Episode Reward: 61.00, Duration: 61
# Step 108/300, Episode Reward: 34.00, Duration: 34
# Step 109/300, Episode Reward: 69.00, Duration: 69
# Step 109/300, Episode Reward: 40.00, Duration: 40
# Step 109/300, Episode Reward: 25.00, Duration: 25
# Step 109/300, Episode Reward: 37.00, Duration: 37
# Step 109/300, Episode Reward: 100.00, Duration: 100
# Step 110/300, Episode Reward: 44.00, Duration: 44
# Step 110/300, Episode Reward: 76.00, Duration: 76
# Step 110/300, Episode Reward: 39.00, Duration: 39
# Step 110/300, Episode Reward: 106.00, Duration: 106
# Step 110/300, Episode Reward: 26.00, Duration: 26
# Step 111/300, Episode Reward: 82.00, Duration: 82
# Step 111/300, Episode Reward: 150.00, Duration: 150
# Step 111/300, Episode Reward: 28.00, Duration: 28
# Step 111/300, Episode Reward: 28.00, Duration: 28
# Step 111/300, Episode Reward: 60.00, Duration: 60
# Step 112/300, Episode Reward: 83.00, Duration: 83
# Step 112/300, Episode Reward: 14.00, Duration: 14
# Step 112/300, Episode Reward: 40.00, Duration: 40
# Step 112/300, Episode Reward: 76.00, Duration: 76
# Step 112/300, Episode Reward: 48.00, Duration: 48
# Step 113/300, Episode Reward: 81.00, Duration: 81
# Step 113/300, Episode Reward: 25.00, Duration: 25
# Step 113/300, Episode Reward: 42.00, Duration: 42
# Step 113/300, Episode Reward: 49.00, Duration: 49
# Step 113/300, Episode Reward: 69.00, Duration: 69
# Step 114/300, Episode Reward: 117.00, Duration: 117
# Step 114/300, Episode Reward: 38.00, Duration: 38
# Step 114/300, Episode Reward: 27.00, Duration: 27
# Step 114/300, Episode Reward: 83.00, Duration: 83
# Step 114/300, Episode Reward: 41.00, Duration: 41
# Step 115/300, Episode Reward: 194.00, Duration: 194
# Step 115/300, Episode Reward: 32.00, Duration: 32
# Step 115/300, Episode Reward: 50.00, Duration: 50
# Step 115/300, Episode Reward: 54.00, Duration: 54
# Step 115/300, Episode Reward: 27.00, Duration: 27
# Step 116/300, Episode Reward: 38.00, Duration: 38
# Step 116/300, Episode Reward: 150.00, Duration: 150
# Step 116/300, Episode Reward: 64.00, Duration: 64
# Step 116/300, Episode Reward: 163.00, Duration: 163
# Step 116/300, Episode Reward: 59.00, Duration: 59
# Step 117/300, Episode Reward: 40.00, Duration: 40
# Step 117/300, Episode Reward: 18.00, Duration: 18
# Step 117/300, Episode Reward: 45.00, Duration: 45
# Step 117/300, Episode Reward: 28.00, Duration: 28
# Step 117/300, Episode Reward: 39.00, Duration: 39
# Step 118/300, Episode Reward: 84.00, Duration: 84
# Step 118/300, Episode Reward: 35.00, Duration: 35
# Step 118/300, Episode Reward: 75.00, Duration: 75
# Step 118/300, Episode Reward: 64.00, Duration: 64
# Step 118/300, Episode Reward: 55.00, Duration: 55
# Step 119/300, Episode Reward: 23.00, Duration: 23
# Step 119/300, Episode Reward: 49.00, Duration: 49
# Step 119/300, Episode Reward: 19.00, Duration: 19
# Step 119/300, Episode Reward: 21.00, Duration: 21
# Step 119/300, Episode Reward: 42.00, Duration: 42
# Step 120/300, Episode Reward: 30.00, Duration: 30
# Step 120/300, Episode Reward: 42.00, Duration: 42
# Step 120/300, Episode Reward: 86.00, Duration: 86
# Step 120/300, Episode Reward: 76.00, Duration: 76
# Step 120/300, Episode Reward: 57.00, Duration: 57
# Step 121/300, Episode Reward: 36.00, Duration: 36
# Step 121/300, Episode Reward: 30.00, Duration: 30
# Step 121/300, Episode Reward: 21.00, Duration: 21
# Step 121/300, Episode Reward: 18.00, Duration: 18
# Step 121/300, Episode Reward: 72.00, Duration: 72
# Step 122/300, Episode Reward: 181.00, Duration: 181
# Step 122/300, Episode Reward: 50.00, Duration: 50
# Step 122/300, Episode Reward: 64.00, Duration: 64
# Step 122/300, Episode Reward: 97.00, Duration: 97
# Step 122/300, Episode Reward: 65.00, Duration: 65
# Step 123/300, Episode Reward: 47.00, Duration: 47
# Step 123/300, Episode Reward: 180.00, Duration: 180
# Step 123/300, Episode Reward: 89.00, Duration: 89
# Step 123/300, Episode Reward: 79.00, Duration: 79
# Step 123/300, Episode Reward: 127.00, Duration: 127
# Step 124/300, Episode Reward: 36.00, Duration: 36
# Step 124/300, Episode Reward: 15.00, Duration: 15
# Step 124/300, Episode Reward: 169.00, Duration: 169
# Step 124/300, Episode Reward: 28.00, Duration: 28
# Step 124/300, Episode Reward: 152.00, Duration: 152
# Step 125/300, Episode Reward: 148.00, Duration: 148
# Step 125/300, Episode Reward: 126.00, Duration: 126
# Step 125/300, Episode Reward: 37.00, Duration: 37
# Step 125/300, Episode Reward: 90.00, Duration: 90
# Step 125/300, Episode Reward: 80.00, Duration: 80
# Step 126/300, Episode Reward: 64.00, Duration: 64
# Step 126/300, Episode Reward: 84.00, Duration: 84
# Step 126/300, Episode Reward: 65.00, Duration: 65
# Step 126/300, Episode Reward: 89.00, Duration: 89
# Step 126/300, Episode Reward: 38.00, Duration: 38
# Step 127/300, Episode Reward: 108.00, Duration: 108
# Step 127/300, Episode Reward: 83.00, Duration: 83
# Step 127/300, Episode Reward: 51.00, Duration: 51
# Step 127/300, Episode Reward: 63.00, Duration: 63
# Step 127/300, Episode Reward: 46.00, Duration: 46
# Step 128/300, Episode Reward: 88.00, Duration: 88
# Step 128/300, Episode Reward: 64.00, Duration: 64
# Step 128/300, Episode Reward: 100.00, Duration: 100
# Step 128/300, Episode Reward: 43.00, Duration: 43
# Step 128/300, Episode Reward: 80.00, Duration: 80
# Step 129/300, Episode Reward: 147.00, Duration: 147
# Step 129/300, Episode Reward: 96.00, Duration: 96
# Step 129/300, Episode Reward: 58.00, Duration: 58
# Step 129/300, Episode Reward: 59.00, Duration: 59
# Step 129/300, Episode Reward: 56.00, Duration: 56
# Step 130/300, Episode Reward: 30.00, Duration: 30
# Step 130/300, Episode Reward: 57.00, Duration: 57
# Step 130/300, Episode Reward: 125.00, Duration: 125
# Step 130/300, Episode Reward: 44.00, Duration: 44
# Step 130/300, Episode Reward: 20.00, Duration: 20
# Step 131/300, Episode Reward: 77.00, Duration: 77
# Step 131/300, Episode Reward: 183.00, Duration: 183
# Step 131/300, Episode Reward: 51.00, Duration: 51
# Step 131/300, Episode Reward: 113.00, Duration: 113
# Step 131/300, Episode Reward: 92.00, Duration: 92
# Step 132/300, Episode Reward: 111.00, Duration: 111
# Step 132/300, Episode Reward: 33.00, Duration: 33
# Step 132/300, Episode Reward: 62.00, Duration: 62
# Step 132/300, Episode Reward: 106.00, Duration: 106
# Step 132/300, Episode Reward: 34.00, Duration: 34
# Step 133/300, Episode Reward: 140.00, Duration: 140
# Step 133/300, Episode Reward: 44.00, Duration: 44
# Step 133/300, Episode Reward: 32.00, Duration: 32
# Step 133/300, Episode Reward: 75.00, Duration: 75
# Step 133/300, Episode Reward: 102.00, Duration: 102
# Step 134/300, Episode Reward: 88.00, Duration: 88
# Step 134/300, Episode Reward: 50.00, Duration: 50
# Step 134/300, Episode Reward: 25.00, Duration: 25
# Step 134/300, Episode Reward: 145.00, Duration: 145
# Step 134/300, Episode Reward: 179.00, Duration: 179
# Step 135/300, Episode Reward: 53.00, Duration: 53
# Step 135/300, Episode Reward: 19.00, Duration: 19
# Step 135/300, Episode Reward: 62.00, Duration: 62
# Step 135/300, Episode Reward: 40.00, Duration: 40
# Step 135/300, Episode Reward: 95.00, Duration: 95
# Step 136/300, Episode Reward: 112.00, Duration: 112
# Step 136/300, Episode Reward: 107.00, Duration: 107
# Step 136/300, Episode Reward: 62.00, Duration: 62
# Step 136/300, Episode Reward: 160.00, Duration: 160
# Step 136/300, Episode Reward: 27.00, Duration: 27
# Step 137/300, Episode Reward: 165.00, Duration: 165
# Step 137/300, Episode Reward: 129.00, Duration: 129
# Step 137/300, Episode Reward: 107.00, Duration: 107
# Step 137/300, Episode Reward: 97.00, Duration: 97
# Step 137/300, Episode Reward: 171.00, Duration: 171
# Step 138/300, Episode Reward: 158.00, Duration: 158
# Step 138/300, Episode Reward: 97.00, Duration: 97
# Step 138/300, Episode Reward: 130.00, Duration: 130
# Step 138/300, Episode Reward: 52.00, Duration: 52
# Step 138/300, Episode Reward: 21.00, Duration: 21
# Step 139/300, Episode Reward: 167.00, Duration: 167
# Step 139/300, Episode Reward: 70.00, Duration: 70
# Step 139/300, Episode Reward: 133.00, Duration: 133
# Step 139/300, Episode Reward: 68.00, Duration: 68
# Step 139/300, Episode Reward: 98.00, Duration: 98
# Step 140/300, Episode Reward: 94.00, Duration: 94
# Step 140/300, Episode Reward: 108.00, Duration: 108
# Step 140/300, Episode Reward: 111.00, Duration: 111
# Step 140/300, Episode Reward: 138.00, Duration: 138
# Step 140/300, Episode Reward: 35.00, Duration: 35
# Step 141/300, Episode Reward: 189.00, Duration: 189
# Step 141/300, Episode Reward: 35.00, Duration: 35
# Step 141/300, Episode Reward: 103.00, Duration: 103
# Step 141/300, Episode Reward: 190.00, Duration: 190
# Step 141/300, Episode Reward: 148.00, Duration: 148
# Step 142/300, Episode Reward: 117.00, Duration: 117
# Step 142/300, Episode Reward: 47.00, Duration: 47
# Step 142/300, Episode Reward: 68.00, Duration: 68
# Step 142/300, Episode Reward: 123.00, Duration: 123
# Step 142/300, Episode Reward: 120.00, Duration: 120
# Step 143/300, Episode Reward: 78.00, Duration: 78
# Step 143/300, Episode Reward: 94.00, Duration: 94
# Step 143/300, Episode Reward: 30.00, Duration: 30
# Step 143/300, Episode Reward: 280.00, Duration: 280
# Step 143/300, Episode Reward: 262.00, Duration: 262
# Step 144/300, Episode Reward: 34.00, Duration: 34
# Step 144/300, Episode Reward: 61.00, Duration: 61
# Step 144/300, Episode Reward: 238.00, Duration: 238
# Step 144/300, Episode Reward: 70.00, Duration: 70
# Step 144/300, Episode Reward: 100.00, Duration: 100
# Step 145/300, Episode Reward: 72.00, Duration: 72
# Step 145/300, Episode Reward: 55.00, Duration: 55
# Step 145/300, Episode Reward: 35.00, Duration: 35
# Step 145/300, Episode Reward: 67.00, Duration: 67
# Step 145/300, Episode Reward: 176.00, Duration: 176
# Step 146/300, Episode Reward: 57.00, Duration: 57
# Step 146/300, Episode Reward: 137.00, Duration: 137
# Step 146/300, Episode Reward: 70.00, Duration: 70
# Step 146/300, Episode Reward: 104.00, Duration: 104
# Step 146/300, Episode Reward: 136.00, Duration: 136
# Step 147/300, Episode Reward: 83.00, Duration: 83
# Step 147/300, Episode Reward: 114.00, Duration: 114
# Step 147/300, Episode Reward: 156.00, Duration: 156
# Step 147/300, Episode Reward: 107.00, Duration: 107
# Step 147/300, Episode Reward: 161.00, Duration: 161
# Step 148/300, Episode Reward: 147.00, Duration: 147
# Step 148/300, Episode Reward: 48.00, Duration: 48
# Step 148/300, Episode Reward: 78.00, Duration: 78
# Step 148/300, Episode Reward: 64.00, Duration: 64
# Step 148/300, Episode Reward: 143.00, Duration: 143
# Step 149/300, Episode Reward: 163.00, Duration: 163
# Step 149/300, Episode Reward: 133.00, Duration: 133
# Step 149/300, Episode Reward: 102.00, Duration: 102
# Step 149/300, Episode Reward: 160.00, Duration: 160
# Step 149/300, Episode Reward: 31.00, Duration: 31
# Step 150/300, Episode Reward: 77.00, Duration: 77
# Step 150/300, Episode Reward: 184.00, Duration: 184
# Step 150/300, Episode Reward: 113.00, Duration: 113
# Step 150/300, Episode Reward: 140.00, Duration: 140
# Step 150/300, Episode Reward: 56.00, Duration: 56
# Step 151/300, Episode Reward: 43.00, Duration: 43
# Step 151/300, Episode Reward: 109.00, Duration: 109
# Step 151/300, Episode Reward: 69.00, Duration: 69
# Step 151/300, Episode Reward: 55.00, Duration: 55
# Step 151/300, Episode Reward: 211.00, Duration: 211
# Step 152/300, Episode Reward: 51.00, Duration: 51
# Step 152/300, Episode Reward: 34.00, Duration: 34
# Step 152/300, Episode Reward: 108.00, Duration: 108
# Step 152/300, Episode Reward: 71.00, Duration: 71
# Step 152/300, Episode Reward: 83.00, Duration: 83
# Step 153/300, Episode Reward: 113.00, Duration: 113
# Step 153/300, Episode Reward: 126.00, Duration: 126
# Step 153/300, Episode Reward: 137.00, Duration: 137
# Step 153/300, Episode Reward: 130.00, Duration: 130
# Step 153/300, Episode Reward: 138.00, Duration: 138
# Step 154/300, Episode Reward: 138.00, Duration: 138
# Step 154/300, Episode Reward: 65.00, Duration: 65
# Step 154/300, Episode Reward: 97.00, Duration: 97
# Step 154/300, Episode Reward: 62.00, Duration: 62
# Step 154/300, Episode Reward: 93.00, Duration: 93
# Step 155/300, Episode Reward: 80.00, Duration: 80
# Step 155/300, Episode Reward: 87.00, Duration: 87
# Step 155/300, Episode Reward: 95.00, Duration: 95
# Step 155/300, Episode Reward: 202.00, Duration: 202
# Step 155/300, Episode Reward: 90.00, Duration: 90
# Step 156/300, Episode Reward: 92.00, Duration: 92
# Step 156/300, Episode Reward: 130.00, Duration: 130
# Step 156/300, Episode Reward: 212.00, Duration: 212
# Step 156/300, Episode Reward: 123.00, Duration: 123
# Step 156/300, Episode Reward: 117.00, Duration: 117
# Step 157/300, Episode Reward: 128.00, Duration: 128
# Step 157/300, Episode Reward: 22.00, Duration: 22
# Step 157/300, Episode Reward: 226.00, Duration: 226
# Step 157/300, Episode Reward: 133.00, Duration: 133
# Step 157/300, Episode Reward: 66.00, Duration: 66
# Step 158/300, Episode Reward: 67.00, Duration: 67
# Step 158/300, Episode Reward: 63.00, Duration: 63
# Step 158/300, Episode Reward: 99.00, Duration: 99
# Step 158/300, Episode Reward: 177.00, Duration: 177
# Step 158/300, Episode Reward: 131.00, Duration: 131
# Step 159/300, Episode Reward: 124.00, Duration: 124
# Step 159/300, Episode Reward: 85.00, Duration: 85
# Step 159/300, Episode Reward: 124.00, Duration: 124
# Step 159/300, Episode Reward: 128.00, Duration: 128
# Step 159/300, Episode Reward: 140.00, Duration: 140
# Step 160/300, Episode Reward: 179.00, Duration: 179
# Step 160/300, Episode Reward: 177.00, Duration: 177
# Step 160/300, Episode Reward: 264.00, Duration: 264
# Step 160/300, Episode Reward: 147.00, Duration: 147
# Step 160/300, Episode Reward: 73.00, Duration: 73
# Step 161/300, Episode Reward: 356.00, Duration: 356
# Step 161/300, Episode Reward: 110.00, Duration: 110
# Step 161/300, Episode Reward: 82.00, Duration: 82
# Step 161/300, Episode Reward: 73.00, Duration: 73
# Step 161/300, Episode Reward: 105.00, Duration: 105
# Step 162/300, Episode Reward: 93.00, Duration: 93
# Step 162/300, Episode Reward: 58.00, Duration: 58
# Step 162/300, Episode Reward: 107.00, Duration: 107
# Step 162/300, Episode Reward: 117.00, Duration: 117
# Step 162/300, Episode Reward: 215.00, Duration: 215
# Step 163/300, Episode Reward: 229.00, Duration: 229
# Step 163/300, Episode Reward: 211.00, Duration: 211
# Step 163/300, Episode Reward: 210.00, Duration: 210
# Step 163/300, Episode Reward: 221.00, Duration: 221
# Step 163/300, Episode Reward: 185.00, Duration: 185
# Step 164/300, Episode Reward: 104.00, Duration: 104
# Step 164/300, Episode Reward: 248.00, Duration: 248
# Step 164/300, Episode Reward: 166.00, Duration: 166
# Step 164/300, Episode Reward: 47.00, Duration: 47
# Step 164/300, Episode Reward: 160.00, Duration: 160
# Step 165/300, Episode Reward: 70.00, Duration: 70
# Step 165/300, Episode Reward: 101.00, Duration: 101
# Step 165/300, Episode Reward: 144.00, Duration: 144
# Step 165/300, Episode Reward: 305.00, Duration: 305
# Step 165/300, Episode Reward: 250.00, Duration: 250
# Step 166/300, Episode Reward: 113.00, Duration: 113
# Step 166/300, Episode Reward: 120.00, Duration: 120
# Step 166/300, Episode Reward: 30.00, Duration: 30
# Step 166/300, Episode Reward: 128.00, Duration: 128
# Step 166/300, Episode Reward: 130.00, Duration: 130
# Step 167/300, Episode Reward: 261.00, Duration: 261
# Step 167/300, Episode Reward: 46.00, Duration: 46
# Step 167/300, Episode Reward: 150.00, Duration: 150
# Step 167/300, Episode Reward: 42.00, Duration: 42
# Step 167/300, Episode Reward: 276.00, Duration: 276
# Step 168/300, Episode Reward: 135.00, Duration: 135
# Step 168/300, Episode Reward: 235.00, Duration: 235
# Step 168/300, Episode Reward: 142.00, Duration: 142
# Step 168/300, Episode Reward: 180.00, Duration: 180
# Step 168/300, Episode Reward: 194.00, Duration: 194
# Step 169/300, Episode Reward: 201.00, Duration: 201
# Step 169/300, Episode Reward: 123.00, Duration: 123
# Step 169/300, Episode Reward: 223.00, Duration: 223
# Step 169/300, Episode Reward: 143.00, Duration: 143
# Step 169/300, Episode Reward: 123.00, Duration: 123
# Step 170/300, Episode Reward: 280.00, Duration: 280
# Step 170/300, Episode Reward: 135.00, Duration: 135
# Step 170/300, Episode Reward: 160.00, Duration: 160
# Step 170/300, Episode Reward: 187.00, Duration: 187
# Step 170/300, Episode Reward: 158.00, Duration: 158
# Step 171/300, Episode Reward: 283.00, Duration: 283
# Step 171/300, Episode Reward: 149.00, Duration: 149
# Step 171/300, Episode Reward: 197.00, Duration: 197
# Step 171/300, Episode Reward: 133.00, Duration: 133
# Step 171/300, Episode Reward: 164.00, Duration: 164
# Step 172/300, Episode Reward: 237.00, Duration: 237
# Step 172/300, Episode Reward: 147.00, Duration: 147
# Step 172/300, Episode Reward: 158.00, Duration: 158
# Step 172/300, Episode Reward: 187.00, Duration: 187
# Step 172/300, Episode Reward: 58.00, Duration: 58
# Step 173/300, Episode Reward: 231.00, Duration: 231
# Step 173/300, Episode Reward: 110.00, Duration: 110
# Step 173/300, Episode Reward: 310.00, Duration: 310
# Step 173/300, Episode Reward: 153.00, Duration: 153
# Step 173/300, Episode Reward: 197.00, Duration: 197
# Step 174/300, Episode Reward: 153.00, Duration: 153
# Step 174/300, Episode Reward: 259.00, Duration: 259
# Step 174/300, Episode Reward: 49.00, Duration: 49
# Step 174/300, Episode Reward: 223.00, Duration: 223
# Step 174/300, Episode Reward: 129.00, Duration: 129
# Step 175/300, Episode Reward: 283.00, Duration: 283
# Step 175/300, Episode Reward: 120.00, Duration: 120
# Step 175/300, Episode Reward: 42.00, Duration: 42
# Step 175/300, Episode Reward: 108.00, Duration: 108
# Step 175/300, Episode Reward: 134.00, Duration: 134
# Step 176/300, Episode Reward: 193.00, Duration: 193
# Step 176/300, Episode Reward: 262.00, Duration: 262
# Step 176/300, Episode Reward: 197.00, Duration: 197
# Step 176/300, Episode Reward: 129.00, Duration: 129
# Step 176/300, Episode Reward: 228.00, Duration: 228
# Step 177/300, Episode Reward: 161.00, Duration: 161
# Step 177/300, Episode Reward: 269.00, Duration: 269
# Step 177/300, Episode Reward: 102.00, Duration: 102
# Step 177/300, Episode Reward: 52.00, Duration: 52
# Step 177/300, Episode Reward: 326.00, Duration: 326
# Step 178/300, Episode Reward: 78.00, Duration: 78
# Step 178/300, Episode Reward: 83.00, Duration: 83
# Step 178/300, Episode Reward: 107.00, Duration: 107
# Step 178/300, Episode Reward: 296.00, Duration: 296
# Step 178/300, Episode Reward: 93.00, Duration: 93
# Step 179/300, Episode Reward: 266.00, Duration: 266
# Step 179/300, Episode Reward: 146.00, Duration: 146
# Step 179/300, Episode Reward: 140.00, Duration: 140
# Step 179/300, Episode Reward: 34.00, Duration: 34
# Step 179/300, Episode Reward: 125.00, Duration: 125
# Step 180/300, Episode Reward: 417.00, Duration: 417
# Step 180/300, Episode Reward: 46.00, Duration: 46
# Step 180/300, Episode Reward: 361.00, Duration: 361
# Step 180/300, Episode Reward: 147.00, Duration: 147
# Step 180/300, Episode Reward: 107.00, Duration: 107
# Step 181/300, Episode Reward: 72.00, Duration: 72
# Step 181/300, Episode Reward: 44.00, Duration: 44
# Step 181/300, Episode Reward: 358.00, Duration: 358
# Step 181/300, Episode Reward: 159.00, Duration: 159
# Step 181/300, Episode Reward: 144.00, Duration: 144
# Step 182/300, Episode Reward: 293.00, Duration: 293
# Step 182/300, Episode Reward: 68.00, Duration: 68
# Step 182/300, Episode Reward: 286.00, Duration: 286
# Step 182/300, Episode Reward: 348.00, Duration: 348
# Step 182/300, Episode Reward: 90.00, Duration: 90
# Step 183/300, Episode Reward: 75.00, Duration: 75
# Step 183/300, Episode Reward: 135.00, Duration: 135
# Step 183/300, Episode Reward: 69.00, Duration: 69
# Step 183/300, Episode Reward: 199.00, Duration: 199
# Step 183/300, Episode Reward: 115.00, Duration: 115
# Step 184/300, Episode Reward: 113.00, Duration: 113
# Step 184/300, Episode Reward: 130.00, Duration: 130
# Step 184/300, Episode Reward: 188.00, Duration: 188
# Step 184/300, Episode Reward: 30.00, Duration: 30
# Step 184/300, Episode Reward: 207.00, Duration: 207
# Step 185/300, Episode Reward: 131.00, Duration: 131
# Step 185/300, Episode Reward: 137.00, Duration: 137
# Step 185/300, Episode Reward: 180.00, Duration: 180
# Step 185/300, Episode Reward: 179.00, Duration: 179
# Step 185/300, Episode Reward: 218.00, Duration: 218
# Step 186/300, Episode Reward: 129.00, Duration: 129
# Step 186/300, Episode Reward: 143.00, Duration: 143
# Step 186/300, Episode Reward: 75.00, Duration: 75
# Step 186/300, Episode Reward: 38.00, Duration: 38
# Step 186/300, Episode Reward: 149.00, Duration: 149
# Step 187/300, Episode Reward: 167.00, Duration: 167
# Step 187/300, Episode Reward: 134.00, Duration: 134
# Step 187/300, Episode Reward: 104.00, Duration: 104
# Step 187/300, Episode Reward: 95.00, Duration: 95
# Step 187/300, Episode Reward: 83.00, Duration: 83
# Step 188/300, Episode Reward: 213.00, Duration: 213
# Step 188/300, Episode Reward: 84.00, Duration: 84
# Step 188/300, Episode Reward: 171.00, Duration: 171
# Step 188/300, Episode Reward: 208.00, Duration: 208
# Step 188/300, Episode Reward: 68.00, Duration: 68
# Step 189/300, Episode Reward: 138.00, Duration: 138
# Step 189/300, Episode Reward: 214.00, Duration: 214
# Step 189/300, Episode Reward: 62.00, Duration: 62
# Step 189/300, Episode Reward: 189.00, Duration: 189
# Step 189/300, Episode Reward: 188.00, Duration: 188
# Step 190/300, Episode Reward: 112.00, Duration: 112
# Step 190/300, Episode Reward: 47.00, Duration: 47
# Step 190/300, Episode Reward: 202.00, Duration: 202
# Step 190/300, Episode Reward: 140.00, Duration: 140
# Step 190/300, Episode Reward: 143.00, Duration: 143
# Step 191/300, Episode Reward: 279.00, Duration: 279
# Step 191/300, Episode Reward: 364.00, Duration: 364
# Step 191/300, Episode Reward: 171.00, Duration: 171
# Step 191/300, Episode Reward: 118.00, Duration: 118
# Step 191/300, Episode Reward: 115.00, Duration: 115
# Step 192/300, Episode Reward: 252.00, Duration: 252
# Step 192/300, Episode Reward: 208.00, Duration: 208
# Step 192/300, Episode Reward: 193.00, Duration: 193
# Step 192/300, Episode Reward: 253.00, Duration: 253
# Step 192/300, Episode Reward: 245.00, Duration: 245
# Step 193/300, Episode Reward: 247.00, Duration: 247
# ...
# Step 239/300, Episode Reward: 200.00, Duration: 200
# Step 239/300, Episode Reward: 132.00, Duration: 132
# Step 240/300, Episode Reward: 306.00, Duration: 306
# Step 240/300, Episode Reward: 146.00, Duration: 146
# Step 240/300, Episode Reward: 243.00, Duration: 243
# Step 240/300, Episode Reward: 105.00, Duration: 105
# Step 240/300, Episode Reward: 420.00, Duration: 420
# Step 241/300, Episode Reward: 112.00, Duration: 112
# Step 241/300, Episode Reward: 161.00, Duration: 161
# Step 241/300, Episode Reward: 287.00, Duration: 287
# Step 241/300, Episode Reward: 431.00, Duration: 431
# Step 241/300, Episode Reward: 273.00, Duration: 273
# Step 242/300, Episode Reward: 322.00, Duration: 322
# Step 242/300, Episode Reward: 177.00, Duration: 177
# Step 242/300, Episode Reward: 107.00, Duration: 107
# Step 242/300, Episode Reward: 118.00, Duration: 118
# Step 242/300, Episode Reward: 427.00, Duration: 427
# Step 243/300, Episode Reward: 500.00, Duration: 500
# Step 243/300, Episode Reward: 222.00, Duration: 222
# Step 243/300, Episode Reward: 113.00, Duration: 113
# Step 243/300, Episode Reward: 112.00, Duration: 112
# Step 243/300, Episode Reward: 259.00, Duration: 259
# Step 244/300, Episode Reward: 247.00, Duration: 247
# Step 244/300, Episode Reward: 300.00, Duration: 300
# Step 244/300, Episode Reward: 399.00, Duration: 399
# Step 244/300, Episode Reward: 329.00, Duration: 329
# Step 244/300, Episode Reward: 235.00, Duration: 235
# Step 245/300, Episode Reward: 288.00, Duration: 288
# Step 245/300, Episode Reward: 259.00, Duration: 259
# Step 245/300, Episode Reward: 328.00, Duration: 328
# Step 245/300, Episode Reward: 375.00, Duration: 375
# Step 245/300, Episode Reward: 127.00, Duration: 127
# Step 246/300, Episode Reward: 214.00, Duration: 214
# Step 246/300, Episode Reward: 132.00, Duration: 132
# Step 246/300, Episode Reward: 273.00, Duration: 273
# Step 246/300, Episode Reward: 500.00, Duration: 500
# Step 246/300, Episode Reward: 406.00, Duration: 406
# Step 247/300, Episode Reward: 381.00, Duration: 381
# Step 247/300, Episode Reward: 128.00, Duration: 128
# Step 247/300, Episode Reward: 145.00, Duration: 145
# Step 247/300, Episode Reward: 189.00, Duration: 189
# Step 247/300, Episode Reward: 241.00, Duration: 241
# Step 248/300, Episode Reward: 163.00, Duration: 163
# Step 248/300, Episode Reward: 314.00, Duration: 314
# Step 248/300, Episode Reward: 213.00, Duration: 213
# Step 248/300, Episode Reward: 243.00, Duration: 243
# Step 248/300, Episode Reward: 303.00, Duration: 303
# Step 249/300, Episode Reward: 278.00, Duration: 278
# Step 249/300, Episode Reward: 223.00, Duration: 223
# Step 249/300, Episode Reward: 267.00, Duration: 267
# Step 249/300, Episode Reward: 309.00, Duration: 309
# Step 249/300, Episode Reward: 142.00, Duration: 142
# Step 250/300, Episode Reward: 252.00, Duration: 252
# Step 250/300, Episode Reward: 233.00, Duration: 233
# Step 250/300, Episode Reward: 206.00, Duration: 206
# Step 250/300, Episode Reward: 293.00, Duration: 293
# Step 250/300, Episode Reward: 410.00, Duration: 410
# Step 251/300, Episode Reward: 500.00, Duration: 500
# Step 251/300, Episode Reward: 223.00, Duration: 223
# Step 251/300, Episode Reward: 198.00, Duration: 198
# Step 251/300, Episode Reward: 320.00, Duration: 320
# Step 251/300, Episode Reward: 305.00, Duration: 305
# Step 252/300, Episode Reward: 231.00, Duration: 231
# Step 252/300, Episode Reward: 190.00, Duration: 190
# Step 252/300, Episode Reward: 198.00, Duration: 198
# Step 252/300, Episode Reward: 181.00, Duration: 181
# Step 252/300, Episode Reward: 212.00, Duration: 212
# Step 253/300, Episode Reward: 246.00, Duration: 246
# Step 253/300, Episode Reward: 407.00, Duration: 407
# Step 253/300, Episode Reward: 272.00, Duration: 272
# Step 253/300, Episode Reward: 203.00, Duration: 203
# Step 253/300, Episode Reward: 176.00, Duration: 176
# Step 254/300, Episode Reward: 117.00, Duration: 117
# Step 254/300, Episode Reward: 89.00, Duration: 89
# Step 254/300, Episode Reward: 265.00, Duration: 265
# Step 254/300, Episode Reward: 346.00, Duration: 346
# Step 254/300, Episode Reward: 172.00, Duration: 172
# Step 255/300, Episode Reward: 500.00, Duration: 500
# Step 255/300, Episode Reward: 152.00, Duration: 152
# Step 255/300, Episode Reward: 146.00, Duration: 146
# Step 255/300, Episode Reward: 273.00, Duration: 273
# Step 255/300, Episode Reward: 214.00, Duration: 214
# Step 256/300, Episode Reward: 171.00, Duration: 171
# Step 256/300, Episode Reward: 297.00, Duration: 297
# Step 256/300, Episode Reward: 199.00, Duration: 199
# Step 256/300, Episode Reward: 214.00, Duration: 214
# Step 256/300, Episode Reward: 294.00, Duration: 294
# Step 257/300, Episode Reward: 245.00, Duration: 245
# Step 257/300, Episode Reward: 153.00, Duration: 153
# Step 257/300, Episode Reward: 149.00, Duration: 149
# Step 257/300, Episode Reward: 279.00, Duration: 279
# Step 257/300, Episode Reward: 346.00, Duration: 346
# Step 258/300, Episode Reward: 195.00, Duration: 195
# Step 258/300, Episode Reward: 262.00, Duration: 262
# Step 258/300, Episode Reward: 203.00, Duration: 203
# Step 258/300, Episode Reward: 404.00, Duration: 404
# Step 258/300, Episode Reward: 215.00, Duration: 215
# Step 259/300, Episode Reward: 317.00, Duration: 317
# Step 259/300, Episode Reward: 449.00, Duration: 449
# Step 259/300, Episode Reward: 331.00, Duration: 331
# Step 259/300, Episode Reward: 196.00, Duration: 196
# Step 259/300, Episode Reward: 169.00, Duration: 169
# Step 260/300, Episode Reward: 88.00, Duration: 88
# Step 260/300, Episode Reward: 424.00, Duration: 424
# Step 260/300, Episode Reward: 241.00, Duration: 241
# Step 260/300, Episode Reward: 264.00, Duration: 264
# Step 260/300, Episode Reward: 480.00, Duration: 480
# Step 261/300, Episode Reward: 295.00, Duration: 295
# Step 261/300, Episode Reward: 460.00, Duration: 460
# Step 261/300, Episode Reward: 231.00, Duration: 231
# Step 261/300, Episode Reward: 296.00, Duration: 296
# Step 261/300, Episode Reward: 287.00, Duration: 287
# Step 262/300, Episode Reward: 373.00, Duration: 373
# Step 262/300, Episode Reward: 221.00, Duration: 221
# Step 262/300, Episode Reward: 164.00, Duration: 164
# Step 262/300, Episode Reward: 263.00, Duration: 263
# Step 262/300, Episode Reward: 120.00, Duration: 120
# Step 263/300, Episode Reward: 137.00, Duration: 137
# Step 263/300, Episode Reward: 288.00, Duration: 288
# Step 263/300, Episode Reward: 200.00, Duration: 200
# Step 263/300, Episode Reward: 233.00, Duration: 233
# Step 263/300, Episode Reward: 327.00, Duration: 327
# Step 264/300, Episode Reward: 500.00, Duration: 500
# Step 264/300, Episode Reward: 327.00, Duration: 327
# Step 264/300, Episode Reward: 299.00, Duration: 299
# Step 264/300, Episode Reward: 279.00, Duration: 279
# Step 264/300, Episode Reward: 209.00, Duration: 209
# Step 265/300, Episode Reward: 261.00, Duration: 261
# Step 265/300, Episode Reward: 339.00, Duration: 339
# Step 265/300, Episode Reward: 291.00, Duration: 291
# Step 265/300, Episode Reward: 253.00, Duration: 253
# Step 265/300, Episode Reward: 317.00, Duration: 317
# Step 266/300, Episode Reward: 334.00, Duration: 334
# Step 266/300, Episode Reward: 135.00, Duration: 135
# Step 266/300, Episode Reward: 167.00, Duration: 167
# Step 266/300, Episode Reward: 173.00, Duration: 173
# Step 266/300, Episode Reward: 368.00, Duration: 368
# Step 267/300, Episode Reward: 361.00, Duration: 361
# Step 267/300, Episode Reward: 384.00, Duration: 384
# Step 267/300, Episode Reward: 186.00, Duration: 186
# Step 267/300, Episode Reward: 224.00, Duration: 224
# Step 267/300, Episode Reward: 239.00, Duration: 239
# Step 268/300, Episode Reward: 427.00, Duration: 427
# Step 268/300, Episode Reward: 245.00, Duration: 245
# Step 268/300, Episode Reward: 262.00, Duration: 262
# Step 268/300, Episode Reward: 405.00, Duration: 405
# Step 268/300, Episode Reward: 347.00, Duration: 347
# Step 269/300, Episode Reward: 335.00, Duration: 335
# Step 269/300, Episode Reward: 240.00, Duration: 240
# Step 269/300, Episode Reward: 267.00, Duration: 267
# Step 269/300, Episode Reward: 183.00, Duration: 183
# Step 269/300, Episode Reward: 384.00, Duration: 384
# Step 270/300, Episode Reward: 178.00, Duration: 178
# Step 270/300, Episode Reward: 239.00, Duration: 239
# Step 270/300, Episode Reward: 47.00, Duration: 47
# Step 270/300, Episode Reward: 175.00, Duration: 175
# Step 270/300, Episode Reward: 500.00, Duration: 500
# Step 271/300, Episode Reward: 345.00, Duration: 345
# Step 271/300, Episode Reward: 500.00, Duration: 500
# Step 271/300, Episode Reward: 373.00, Duration: 373
# Step 271/300, Episode Reward: 136.00, Duration: 136
# Step 271/300, Episode Reward: 223.00, Duration: 223
# Step 272/300, Episode Reward: 234.00, Duration: 234
# Step 272/300, Episode Reward: 262.00, Duration: 262
# Step 272/300, Episode Reward: 166.00, Duration: 166
# Step 272/300, Episode Reward: 217.00, Duration: 217
# Step 272/300, Episode Reward: 242.00, Duration: 242
# Step 273/300, Episode Reward: 298.00, Duration: 298
# Step 273/300, Episode Reward: 161.00, Duration: 161
# Step 273/300, Episode Reward: 333.00, Duration: 333
# Step 273/300, Episode Reward: 354.00, Duration: 354
# Step 273/300, Episode Reward: 330.00, Duration: 330
# Step 274/300, Episode Reward: 191.00, Duration: 191
# Step 274/300, Episode Reward: 371.00, Duration: 371
# Step 274/300, Episode Reward: 402.00, Duration: 402
# Step 274/300, Episode Reward: 246.00, Duration: 246
# Step 274/300, Episode Reward: 436.00, Duration: 436
# Step 275/300, Episode Reward: 284.00, Duration: 284
# Step 275/300, Episode Reward: 313.00, Duration: 313
# Step 275/300, Episode Reward: 361.00, Duration: 361
# Step 275/300, Episode Reward: 207.00, Duration: 207
# Step 275/300, Episode Reward: 403.00, Duration: 403
# Step 276/300, Episode Reward: 357.00, Duration: 357
# Step 276/300, Episode Reward: 286.00, Duration: 286
# Step 276/300, Episode Reward: 288.00, Duration: 288
# Step 276/300, Episode Reward: 344.00, Duration: 344
# Step 276/300, Episode Reward: 224.00, Duration: 224
# Step 277/300, Episode Reward: 127.00, Duration: 127
# Step 277/300, Episode Reward: 127.00, Duration: 127
# Step 277/300, Episode Reward: 254.00, Duration: 254
# Step 277/300, Episode Reward: 105.00, Duration: 105
# Step 277/300, Episode Reward: 115.00, Duration: 115
# Step 278/300, Episode Reward: 500.00, Duration: 500
# Step 278/300, Episode Reward: 224.00, Duration: 224
# Step 278/300, Episode Reward: 174.00, Duration: 174
# Step 278/300, Episode Reward: 81.00, Duration: 81
# Step 278/300, Episode Reward: 157.00, Duration: 157
# Step 279/300, Episode Reward: 372.00, Duration: 372
# Step 279/300, Episode Reward: 374.00, Duration: 374
# Step 279/300, Episode Reward: 211.00, Duration: 211
# Step 279/300, Episode Reward: 428.00, Duration: 428
# Step 279/300, Episode Reward: 117.00, Duration: 117
# Step 280/300, Episode Reward: 308.00, Duration: 308
# Step 280/300, Episode Reward: 146.00, Duration: 146
# Step 280/300, Episode Reward: 185.00, Duration: 185
# Step 280/300, Episode Reward: 250.00, Duration: 250
# Step 280/300, Episode Reward: 353.00, Duration: 353
# Step 281/300, Episode Reward: 500.00, Duration: 500
# Step 281/300, Episode Reward: 312.00, Duration: 312
# Step 281/300, Episode Reward: 413.00, Duration: 413
# Step 281/300, Episode Reward: 470.00, Duration: 470
# Step 281/300, Episode Reward: 238.00, Duration: 238
# Step 282/300, Episode Reward: 375.00, Duration: 375
# Step 282/300, Episode Reward: 280.00, Duration: 280
# Step 282/300, Episode Reward: 429.00, Duration: 429
# Step 282/300, Episode Reward: 300.00, Duration: 300
# Step 282/300, Episode Reward: 344.00, Duration: 344
# Step 283/300, Episode Reward: 157.00, Duration: 157
# Step 283/300, Episode Reward: 264.00, Duration: 264
# Step 283/300, Episode Reward: 212.00, Duration: 212
# Step 283/300, Episode Reward: 194.00, Duration: 194
# Step 283/300, Episode Reward: 227.00, Duration: 227
# Step 284/300, Episode Reward: 277.00, Duration: 277
# Step 284/300, Episode Reward: 248.00, Duration: 248
# Step 284/300, Episode Reward: 395.00, Duration: 395
# Step 284/300, Episode Reward: 500.00, Duration: 500
# Step 284/300, Episode Reward: 297.00, Duration: 297
# Step 285/300, Episode Reward: 139.00, Duration: 139
# Step 285/300, Episode Reward: 182.00, Duration: 182
# Step 285/300, Episode Reward: 161.00, Duration: 161
# Step 285/300, Episode Reward: 180.00, Duration: 180
# Step 285/300, Episode Reward: 377.00, Duration: 377
# Step 286/300, Episode Reward: 500.00, Duration: 500
# Step 286/300, Episode Reward: 340.00, Duration: 340
# Step 286/300, Episode Reward: 109.00, Duration: 109
# Step 286/300, Episode Reward: 490.00, Duration: 490
# Step 286/300, Episode Reward: 500.00, Duration: 500
# Step 287/300, Episode Reward: 406.00, Duration: 406
# Step 287/300, Episode Reward: 162.00, Duration: 162
# Step 287/300, Episode Reward: 500.00, Duration: 500
# Step 287/300, Episode Reward: 434.00, Duration: 434
# Step 287/300, Episode Reward: 437.00, Duration: 437
# Step 288/300, Episode Reward: 155.00, Duration: 155
# Step 288/300, Episode Reward: 290.00, Duration: 290
# Step 288/300, Episode Reward: 285.00, Duration: 285
# Step 288/300, Episode Reward: 360.00, Duration: 360
# Step 288/300, Episode Reward: 170.00, Duration: 170
# Step 289/300, Episode Reward: 156.00, Duration: 156
# Step 289/300, Episode Reward: 298.00, Duration: 298
# Step 289/300, Episode Reward: 207.00, Duration: 207
# Step 289/300, Episode Reward: 310.00, Duration: 310
# Step 289/300, Episode Reward: 307.00, Duration: 307
# Step 290/300, Episode Reward: 494.00, Duration: 494
# Step 290/300, Episode Reward: 367.00, Duration: 367
# Step 290/300, Episode Reward: 368.00, Duration: 368
# Step 290/300, Episode Reward: 224.00, Duration: 224
# Step 290/300, Episode Reward: 173.00, Duration: 173
# Step 291/300, Episode Reward: 193.00, Duration: 193
# Step 291/300, Episode Reward: 250.00, Duration: 250
# Step 291/300, Episode Reward: 432.00, Duration: 432
# Step 291/300, Episode Reward: 304.00, Duration: 304
# Step 291/300, Episode Reward: 283.00, Duration: 283
# Step 292/300, Episode Reward: 248.00, Duration: 248
# Step 292/300, Episode Reward: 292.00, Duration: 292
# Step 292/300, Episode Reward: 225.00, Duration: 225
# Step 292/300, Episode Reward: 418.00, Duration: 418
# Step 292/300, Episode Reward: 219.00, Duration: 219
# Step 293/300, Episode Reward: 176.00, Duration: 176
# Step 293/300, Episode Reward: 146.00, Duration: 146
# Step 293/300, Episode Reward: 298.00, Duration: 298
# Step 293/300, Episode Reward: 261.00, Duration: 261
# Step 293/300, Episode Reward: 320.00, Duration: 320
# Step 294/300, Episode Reward: 160.00, Duration: 160
# Step 294/300, Episode Reward: 438.00, Duration: 438
# Step 294/300, Episode Reward: 133.00, Duration: 133
# Step 294/300, Episode Reward: 129.00, Duration: 129
# Step 294/300, Episode Reward: 323.00, Duration: 323
# Step 295/300, Episode Reward: 271.00, Duration: 271
# Step 295/300, Episode Reward: 500.00, Duration: 500
# Step 295/300, Episode Reward: 145.00, Duration: 145
# Step 295/300, Episode Reward: 304.00, Duration: 304
# Step 295/300, Episode Reward: 121.00, Duration: 121
# Step 296/300, Episode Reward: 500.00, Duration: 500
# Step 296/300, Episode Reward: 259.00, Duration: 259
# Step 296/300, Episode Reward: 89.00, Duration: 89
# Step 296/300, Episode Reward: 144.00, Duration: 144
# Step 296/300, Episode Reward: 500.00, Duration: 500
# Step 297/300, Episode Reward: 108.00, Duration: 108
# Step 297/300, Episode Reward: 257.00, Duration: 257
# Step 297/300, Episode Reward: 119.00, Duration: 119
# Step 297/300, Episode Reward: 236.00, Duration: 236
# Step 297/300, Episode Reward: 164.00, Duration: 164
# Step 298/300, Episode Reward: 135.00, Duration: 135
# Step 298/300, Episode Reward: 500.00, Duration: 500
# Step 298/300, Episode Reward: 500.00, Duration: 500
# Step 298/300, Episode Reward: 401.00, Duration: 401
# Step 298/300, Episode Reward: 361.00, Duration: 361
# Step 299/300, Episode Reward: 370.00, Duration: 370
# Step 299/300, Episode Reward: 135.00, Duration: 135
# Step 299/300, Episode Reward: 246.00, Duration: 246
# Step 299/300, Episode Reward: 290.00, Duration: 290
# Step 299/300, Episode Reward: 160.00, Duration: 160
# Step 300/300, Episode Reward: 403.00, Duration: 403
# Step 300/300, Episode Reward: 346.00, Duration: 346
# Step 300/300, Episode Reward: 500.00, Duration: 500
# Step 300/300, Episode Reward: 226.00, Duration: 226
# Step 300/300, Episode Reward: 207.00, Duration: 207

# %%
plt.plot(train)
plt.xlabel('Episode')
plt.ylabel('Duration')
plt.title('Episode Durations')
plt.show()

# %%
window_size = 20  # Adjust the window size as needed
smoothed_train = np.convolve(train, np.ones(window_size) / window_size, mode='valid')

# Plot the smoothed data
plt.plot(smoothed_train)
plt.xlabel('Episode')
plt.ylabel('Duration')
plt.title('Smoothed Episode Durations')
plt.show()

# %% [markdown]
# ## Cartpole Reinforce Visualization
#
# We visualize the Reinforce policy for the cartpole environment. Update the `video_path` as needed. All generated gifs should be uploaded along with notebook.

# %% [markdown]
# Note that action selection with the Reinforce Agent is stochastic so different runs with the same agent will produce different results. You can re-run the code to observe different interactions with the environment.

# %%
env = gym.make('CartPole-v1', render_mode = 'rgb_array')

frames = []
done=False
state, _ = env.reset(seed=random.randint(0,500))
frames.append(env.render())

while not done:
    torch_state = torch.from_numpy(state)
    action = reinforce_agent.choose_action(torch_state)[0]
    state, reward, done, _, _ = env.step(action)
    frames.append(env.render())

save_frames_as_video(frames, gifname:=f"{base_dir}/cartpole_reinforce.gif", fps=20)

env.close()

ImageWidget(gifname)
# Out:
# Saved 384 individual frames to ./cartpole_reinforce.gif

# %% [markdown]
# ### **Q3**: Compare your results for using DQN and Reinforce. Discuss the performance, convergence, and behavior of the two algorithms. Consider factors such as the stability of learning, the quality of the learned policies, and the behavior of the final policy. (5 pts)
#
# Respond with 2-3 sentences in your responses document.

# %% [markdown]
# ### **SUBMISSION INSTRUCTIONS**
# Congratulations! Last coding assignment completed!
#
# 1.   Upload the `.py` or a `.zip` to **[Coding Assignment 5](https://www.gradescope.com/courses/963234/assignments/6120914/review_grades)**  containing `submission.py`.
#
# 2.   Upload a `.zip `with the written responses <u>*and all generated gifs*</u> to questions in the notebook to **[Coding Assignment 5 Responses](https://www.gradescope.com/courses/963234/assignments/6145269/)**. Your `.zip` should contain:
#
# - `responses.tex/pdf/etc`
# - `taxi_random.gif`
# - `taxi_q_learning.gif`
# - `cartpole_random.gif`
# - `cartpole_dqn.gif`
# - `cartpole_reinforce.gif`
